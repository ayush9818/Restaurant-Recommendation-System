# %%
import pandas as pd
import json

def load_data(file_path, lines=True):
    data = []
    with open(file_path, 'r') as file:
        if lines:
            for line in file:
                data.append(json.loads(line))
        else:
            data = json.load(file)
    return pd.DataFrame(data)

# %%
business_data_path = '/Users/yixie/Downloads/yelp_academic_dataset_business.json'
business_df = load_data(business_data_path)
print(business_df.head())
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %%
business_df[business_df['city'] == 'Philadelphia']
# Out:
#                    business_id                                 name  \
# 3       MTSW4McQd7CbVtyjqoe9mw                   St Honore Pastries
# 15      MUTTqe8uqyMdBl186RmNeA                             Tuna Bar
# 19      ROeacJQwBeh05Rqg7F6TCg                                  BAP
# 28      QdN72BWoyFypdGJhhI5r7g                              Bar One
# 31      Mjboz24M9NlBeiOJKLEd_Q                     DeSandro on Main
# ...                        ...                                  ...
# 150320  wPAaAbFbq5wfLfW0gnYU7g                             Intermix
# 150326  JDM7kiCEmeBc_5W-z6eZZw              2601 Parkway Apartments
# 150329  9U1Igcpe954LoWZRmNc-zg  Hand & Stone Massage And Facial Spa
# 150334  LJ4GjQ1HL6kqvIPpNUNNaQ             Shanti Yoga and Ayurveda
# 150336  WnT9NIzQgLlILjPT0kEcsQ        Adelita Taqueria & Restaurant
#
#                              address          city state postal_code  \
# 3                        935 Race St  Philadelphia    PA       19107
# 15                       205 Race St  Philadelphia    PA       19106
# 19                     1224 South St  Philadelphia    PA       19147
# 28                      767 S 9th St  Philadelphia    PA       19147
# 31                      4105 Main St  Philadelphia    PA       19127
# ...                              ...           ...   ...         ...
# 150320                1718 Walnut St  Philadelphia    PA       19103
# 150326         2601 Pennsylvania Ave  Philadelphia    PA       19130
# 150329  1100 S Columbus Blvd, Ste 24  Philadelphia    PA       19147
# 150334            1638 Pine St, Fl 1  Philadelphia    PA       19103
# 150336                 1108 S 9th St  Philadelphia    PA       19147
#
#          latitude  longitude  stars  review_count  is_open  \
# 3       39.955505 -75.155564    4.0            80        1
# 15      39.953949 -75.143226    4.0           245        1
# 19      39.943223 -75.162568    4.5           205        1
# 28      39.939825 -75.157447    4.0            65        0
# 31      40.022466 -75.218314    3.0            41        0
# ...           ...        ...    ...           ...      ...
# 150320  39.950060 -75.170129    2.0            10        0
# 150326  39.968806 -75.180608    3.0             6        1
# 150329  39.932756 -75.144504    3.0            32        1
# 150334  39.945966 -75.169666    4.5            39        1
# 150336  39.935982 -75.158665    4.5            35        1
#
#                                                attributes  \
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 15      {'RestaurantsReservations': 'True', 'Restauran...
# 19      {'NoiseLevel': 'u'quiet'', 'GoodForMeal': '{'d...
# 28      {'Smoking': 'u'no'', 'NoiseLevel': 'u'average'...
# 31      {'RestaurantsReservations': 'False', 'Caters':...
# ...                                                   ...
# 150320  {'BusinessParking': '{'garage': False, 'street...
# 150326             {'BusinessAcceptsCreditCards': 'True'}
# 150329  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# 150334  {'ByAppointmentOnly': 'True', 'GoodForKids': '...
# 150336  {'WheelchairAccessible': 'False', 'Restaurants...
#
#                                                categories  \
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 15                      Sushi Bars, Restaurants, Japanese
# 19                                    Korean, Restaurants
# 28      Cocktail Bars, Bars, Italian, Nightlife, Resta...
# 31                        Pizza, Restaurants, Salad, Soup
# ...                                                   ...
# 150320                Fashion, Shopping, Women's Clothing
# 150326             Real Estate, Apartments, Home Services
# 150329        Day Spas, Beauty & Spas, Skin Care, Massage
# 150334  Health & Medical, Yoga, Shopping, Naturopathic...
# 150336                               Restaurants, Mexican
#
#                                                     hours
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 15      {'Tuesday': '13:30-22:0', 'Wednesday': '13:30-...
# 19      {'Monday': '11:30-20:30', 'Tuesday': '11:30-20...
# 28      {'Monday': '16:0-0:0', 'Tuesday': '16:0-0:0', ...
# 31      {'Tuesday': '17:0-21:30', 'Wednesday': '17:0-1...
# ...                                                   ...
# 150320  {'Monday': '10:0-19:0', 'Tuesday': '10:0-19:0'...
# 150326                                               None
# 150329  {'Monday': '9:0-22:0', 'Tuesday': '9:0-22:0', ...
# 150334  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 150336  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
#
# [14569 rows x 14 columns]

# %%
import json

# Specify the input and output file paths
input_file_path = '/Users/yixie/Downloads/yelp_academic_dataset_review.json'
output_file_prefix = 'file'

def chunk_json_file(input_file, chunk_size):
    with open(input_file, 'r') as infile:
        chunk = []
        chunk_count = 0

        for line in infile:
            try:
                item = json.loads(line.strip())
                chunk.append(item)

                if len(chunk) == chunk_size:
                    # Save the chunk to a new file
                    output_file_path = f'{output_file_prefix}_{chunk_count}.json'
                    with open(output_file_path, 'w') as outfile:
                        json.dump(chunk, outfile)
                    chunk = []
                    chunk_count += 1
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON: {e}")

        # Save the last chunk if any items are remaining
        if chunk:
            output_file_path = f'{output_file_prefix}_{chunk_count}.json'
            with open(output_file_path, 'w') as outfile:
                json.dump(chunk, outfile)

# Specify your desired chunk size
chunk_size = 1000

# Call the function to create chunks
chunk_json_file(input_file_path, chunk_size)

# %%
import json

# Specify the file path of one of the output files
output_file_path = 'file_0.json'

# Load and print the contents of the file
with open(output_file_path, 'r') as infile:
    chunk_data = json.load(infile)
    print(chunk_data)
# Out:
# [{'review_id': 'KU_O5udG6zpxOg-VcAEodg', 'user_id': 'mh_-eMZ6K5RLWhZyISBhwA', 'business_id': 'XQfwVwDr-v0ZS3_CbbE5Xw', 'stars': 3.0, 'useful': 0, 'funny': 0, 'cool': 0, 'text': "If you decide to eat here, just be aware it is going to take about 2 hours from beginning to end. We have tried it multiple times, because I want to like it! I have been to it's other locations in NJ and never had a bad experience. \n\nThe food is good, but it takes a very long time to come out. The waitstaff is very young, but usually pleasant. We have just had too many experiences where we spent way too long waiting. We usually opt for another diner or restaurant on the weekends, in order to be done quicker.", 'date': '2018-07-07 22:09:11'}, {'review_id': 'BiTunyQ73aT9WBnpR9DZGw', 'user_id': 'OyoGAe7OKpv6SyGZT5g77Q', 'business_id': '7ATYjTIgM3jUlt4UM3IypQ', 'stars': 5.0, 'useful': 1, 'funny': 0, 'cool': 1, 'text': "I've taken a lot of spin classes over the years, and nothing compares to the classes at Body Cycle. From the nice, clean space and amazing bikes, to the welcoming and motivating instructors, every class is a top notch work out.\n\nFor anyone who struggles to fit workouts in, the online scheduling system makes it easy to plan ahead (and there's no need to line up way in advanced like many gyms make you do).\n\nThere is no way I can write this review without giving Russell, the owner of Body Cycle, a shout out. Russell's passion for fitness and cycling is so evident, as is his desire for all of his clients to succeed. He is always dropping in to classes to check in/provide encouragement, and is open to ideas and recommendations from anyone. Russell always wears a smile on his face, even when he's kicking your butt in class!", 'date': '2012-01-03 15:28:18'}, {'review_id': 'saUsX_uimxRlCVr67Z4Jig', 'user_id': '8g_iMtfSiwikVnbP2etR0A', 'business_id': 'YjUWPpI6HXG530lwP-fb2A', 'stars': 3.0, 'useful': 0, 'funny': 0, 'cool': 0, 'text': 'Family diner. Had the buffet. Eclectic assortment: a large chicken leg, fried jalapeño, tamale, two rolled grape leaves, fresh melon. All good. Lots of Mexican choices there. Also has a menu with breakfast served all day long. Friendly, attentive staff. Good place for a casual relaxed meal with no expectations. Next to the Clarion Hotel.', 'date': '2014-02-05 20:30:30'}, {'review_id': 'AqPFMleE6RsU23_auESxiA', 'user_id': '_7bHUi9Uuf5__HHc_Q8guQ', 'business_id': 'kxX2SOes4o-D3ZQBkiMRfA', 'stars': 5.0, 'useful': 1, 'funny': 0, 'cool': 1, 'text': "Wow!  Yummy, different,  delicious.   Our favorite is the lamb curry and korma.  With 10 different kinds of naan!!!  Don't let the outside deter you (because we almost changed our minds)...go in and try something new!   You'll be glad you did!", 'date': '2015-01-04 00:01:03'}, {'review_id': 'Sx8TMOWLNuJBWer-0pcmoA', 'user_id': 'bcjbaE6dDog4jkNY91ncLQ', 'business_id': 'e4Vwtrqf-wpJfwesgvdgxQ', 'stars': 4.0, 'useful': 1, 'funny': 0, 'cool': 1, 'text': "Cute interior and owner (?) gave us tour of upcoming patio/rooftop area which will be great on beautiful days like today. Cheese curds were very good and very filling. Really like that sandwiches come w salad, esp after eating too many curds! Had the onion, gruyere, tomato sandwich. Wasn't too much cheese which I liked. Needed something else...pepper jelly maybe. Would like to see more menu options added such as salads w fun cheeses. Lots of beer and wine as well as limited cocktails. Next time I will try one of the draft wines.", 'date': '2017-01-14 20:54:15'}, {'review_id': 'JrIxlS1TzJ-iCu79ul40cQ', 'user_id': 'eUta8W_HdHMXPzLBBZhL1A', 'business_id': '04UD14gamNjLY0IDYVhHJg', 'stars': 1.0, 'useful': 1, 'funny': 2, 'cool': 1, 'text': "I am a long term frequent customer of this establishment. I just went in to order take out (3 apps) and was told they're too busy to do it. Really? The place is maybe half full at best. Does your dick reach your ass? Yes? Go fuck yourself! I'm a frequent customer AND great tipper. Glad that Kanell ...

# %%
df = pd.DataFrame(chunk_data)
df
# Out:
#                   review_id                 user_id             business_id  \
# 0    KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1    BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2    saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3    AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4    Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# ..                      ...                     ...                     ...
# 995  XMWg7adwVBKqIl_e_TTtuA  syyKcKPFILDysHWmtka-aA  1_hDCN3iioFR3XnUr32ZtA
# 996  BGZ3GtcXhtIEPIkyLVuKDQ  _lgLNzpzf3qmbwySBakxEw  5RzJ2bjU8bLSaN5SuiUpYA
# 997  lm7Q8pH26kqx1gbjCJ16ZQ  Sh_vUlHHY2Kuj14eF8NYZQ  s1PNBO9o5jIgNd5YWUDLXQ
# 998  Lo2giVeSNDvatEAGZRikWQ  YwMD-AVT67fmYRGxnlRSPA  alUk6OwNhofyc90NDMDY-Q
# 999  HBCwI0ahXuni3x030HGKFA  WKe2b_EeLBnZ3lZV5WKYGQ  -Or44IdY51Ukd618kikmtA
#
#      stars  useful  funny  cool  \
# 0      3.0       0      0     0
# 1      5.0       1      0     1
# 2      3.0       0      0     0
# 3      5.0       1      0     1
# 4      4.0       1      0     1
# ..     ...     ...    ...   ...
# 995    5.0       0      0     0
# 996    4.0       1      0     1
# 997    5.0       1      0     0
# 998    5.0       7      1     0
# 999    4.0       0      0     0
#
#                                                   text                 date
# 0    If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1    I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2    Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 3    Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 4    Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15
# ..                                                 ...                  ...
# 995  I Recently vacationed in St. Petersburg with m...  2014-06-28 03:00:56
# 996  Very cool bar attached to the Alexander Hotel....  2016-01-17 16:45:19
# 997  This hotel is a gem in the heart of Philadelph...  2016-02-23 21:31:39
# 998  Was taken here today by a Colombian friend who...  2010-08-22 01:54:23
# 999  My friends and I all got one of each that were...  2016-07-25 06:28:49
#
# [1000 rows x 9 columns]

# %%
merged_df = pd.merge(df, business_df, on='business_id', how='left')

# Print the merged DataFrame
merged_df
# Out:
#                   review_id                 user_id             business_id  \
# 0    KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1    BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2    saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3    AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4    Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# ..                      ...                     ...                     ...
# 995  XMWg7adwVBKqIl_e_TTtuA  syyKcKPFILDysHWmtka-aA  1_hDCN3iioFR3XnUr32ZtA
# 996  BGZ3GtcXhtIEPIkyLVuKDQ  _lgLNzpzf3qmbwySBakxEw  5RzJ2bjU8bLSaN5SuiUpYA
# 997  lm7Q8pH26kqx1gbjCJ16ZQ  Sh_vUlHHY2Kuj14eF8NYZQ  s1PNBO9o5jIgNd5YWUDLXQ
# 998  Lo2giVeSNDvatEAGZRikWQ  YwMD-AVT67fmYRGxnlRSPA  alUk6OwNhofyc90NDMDY-Q
# 999  HBCwI0ahXuni3x030HGKFA  WKe2b_EeLBnZ3lZV5WKYGQ  -Or44IdY51Ukd618kikmtA
#
#      stars_x  useful  funny  cool  \
# 0        3.0       0      0     0
# 1        5.0       1      0     1
# 2        3.0       0      0     0
# 3        5.0       1      0     1
# 4        4.0       1      0     1
# ..       ...     ...    ...   ...
# 995      5.0       0      0     0
# 996      4.0       1      0     1
# 997      5.0       1      0     0
# 998      5.0       7      1     0
# 999      4.0       0      0     0
#
#                                                   text                 date  \
# 0    If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1    I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2    Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 3    Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 4    Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15
# ..                                                 ...                  ...
# 995  I Recently vacationed in St. Petersburg with m...  2014-06-28 03:00:56
# 996  Very cool bar attached to the Alexander Hotel....  2016-01-17 16:45:19
# 997  This hotel is a gem in the heart of Philadelph...  2016-02-23 21:31:39
# 998  Was taken here today by a Colombian friend who...  2010-08-22 01:54:23
# 999  My friends and I all got one of each that were...  2016-07-25 06:28:49
#
#                                    name  ... state postal_code   latitude  \
# 0          Turning Point of North Wales  ...    PA       19454  40.210196
# 1            Body Cycle Spinning Studio  ...    PA       19119  39.952103
# 2                     Kettle Restaurant  ...    AZ       85713  32.207233
# 3                                 Zaika  ...    PA       19114  40.079848
# 4                                  Melt  ...    LA       70119  29.962102
# ..                                  ...  ...   ...         ...        ...
# 995                             Dooners  ...    FL       33701  27.771801
# 996                             Plat 99  ...    IN       46204  39.761769
# 997               The Independent Hotel  ...    PA       19107  39.947781
# 998  Fabio's Chicken Restaurant Takeout  ...    PA       19120  40.023288
# 999                      Federal Donuts  ...    PA       19123  39.964179
#
#       longitude  stars_y  review_count  is_open  \
# 0    -75.223639      3.0           169        1
# 1    -75.172753      5.0           144        0
# 2   -110.980864      3.5            47        1
# 3    -75.025080      4.0           181        1
# 4    -90.087958      4.0            32        0
# ..          ...      ...           ...      ...
# 995  -82.636908      3.5           109        0
# 996  -86.154336      4.5           206        1
# 997  -75.162146      3.5           123        0
# 998  -75.123764      4.5            14        1
# 999  -75.149424      4.0           321        1
#
#                                             attributes  \
# 0    {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
# 1    {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 2    {'RestaurantsReservations': 'True', 'BusinessP...
# 3    {'Caters': 'True', 'Ambience': '{'romantic': F...
# 4    {'BusinessParking': '{'garage': False, 'street...
# ..                                                 ...
# 995  {'BusinessParking': '{'garage': False, 'street...
# 996  {'NoiseLevel': 'u'average'', 'OutdoorSeating':...
# 997  {'BusinessAcceptsCreditCards': 'True', 'WiFi':...
# 998  {'HasTV': 'True', 'BusinessParking': '{'garage...
# 999  {'RestaurantsAttire': ''casual'', 'Restaurants...
#
#                                             categories  \
# 0    Restaurants, Breakfast & Brunch, Food, Juice B...
# 1    Active Life, Cycling Classes, Trainers, Gyms, ...
# 2                      Restaurants, Breakfast & Brunch
# 3                Halal, Pakistani, Restaurants, Indian
# 4    Sandwiches, Beer, Wine & Spirits, Bars, Food, ...
# ..                                                 ...
# 995  Fast Food, Turkish, German, Greek, Mediterrane...
# 996  Event Planning & Services, Art Galleries, Hote...
# 997  Hotels, Hotels & Travel, Event Planning & Serv...
# 998         Latin American, Restaurants, Chicken Wings
# 999  Restaurants, Donuts, Chicken Wings, Food, Coff...
#
#                                                  hours
# 0    {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# 1    {'Monday': '6:30-20:30', 'Tuesday': '6:30-20:3...
# 2                                                 None
# 3    {'Tuesday': '11:0-21:0', 'Wednesday': '11:0-21...
# 4    {'Monday': '0:0-0:0', 'Friday': '11:0-17:0', '...
# ..                                                 ...
# 995  {'Monday': '11:30-15:0', 'Tuesday': '11:30-15:...
# 996  {'Thursday': '19:0-22:0', 'Friday': '19:0-22:0...
# 997  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 998                                               None
# 999  {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...
#
# [1000 rows x 22 columns]

# %%
merged_df[merged_df['city'] == 'Philadelphia']
# Out:
#                   review_id                 user_id             business_id  \
# 1    BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 3    AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 5    JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
# 13   8JFGBuHMoiNDyfcxuWNtrA  smOvOajNG0lS4Pq7d8g4JQ  RZtGWDLCAtuipwaZ-UfjmQ
# 16   oyaMhzBSwfGgemSGuZCdwQ  Dd1jQj7S-BFGqRbApFzCFw  YtSqYv1Q_pOltsVPSx54SA
# ..                      ...                     ...                     ...
# 985  Hvw1Hxmla7phoWVpyxBCHQ  ncWuUSITGNp8Q2-WHjtCLw  u7_3L1NBWgxhBM_B-cmmnA
# 989  z9s96krlSZRoN0XKzCVbAA  Dg2AUgE5DeN9MzAbVk40Vg  8hgo446H2HoYlZocEi1SJw
# 997  lm7Q8pH26kqx1gbjCJ16ZQ  Sh_vUlHHY2Kuj14eF8NYZQ  s1PNBO9o5jIgNd5YWUDLXQ
# 998  Lo2giVeSNDvatEAGZRikWQ  YwMD-AVT67fmYRGxnlRSPA  alUk6OwNhofyc90NDMDY-Q
# 999  HBCwI0ahXuni3x030HGKFA  WKe2b_EeLBnZ3lZV5WKYGQ  -Or44IdY51Ukd618kikmtA
#
#      stars_x  useful  funny  cool  \
# 1        5.0       1      0     1
# 3        5.0       1      0     1
# 5        1.0       1      2     1
# 13       4.0       0      0     0
# 16       5.0       0      0     0
# ..       ...     ...    ...   ...
# 985      2.0       0      0     0
# 989      5.0       0      0     0
# 997      5.0       1      0     0
# 998      5.0       7      1     0
# 999      4.0       0      0     0
#
#                                                   text                 date  \
# 1    I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 3    Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 5    I am a long term frequent customer of this est...  2015-09-23 23:10:31
# 13   Good food--loved the gnocchi with marinara\nth...  2009-10-14 19:57:14
# 16   Tremendous service (Big shout out to Douglas) ...  2013-06-24 11:21:25
# ..                                                 ...                  ...
# 985  I could be craving pizza and be walking by and...  2014-11-12 18:28:06
# 989  This is a great place to bring the kids to. Th...  2013-01-27 18:29:40
# 997  This hotel is a gem in the heart of Philadelph...  2016-02-23 21:31:39
# 998  Was taken here today by a Colombian friend who...  2010-08-22 01:54:23
# 999  My friends and I all got one of each that were...  2016-07-25 06:28:49
#
#                                    name  ... state postal_code   latitude  \
# 1            Body Cycle Spinning Studio  ...    PA       19119  39.952103
# 3                                 Zaika  ...    PA       19114  40.079848
# 5                              Dmitri's  ...    PA       19147  39.938013
# 13                            LaScala's  ...    PA       19106  39.949529
# 16                    Rittenhouse Grill  ...    PA       19103  39.948949
# ..                                  ...  ...   ...         ...        ...
# 985                      Pizzeria Vetri  ...    PA       19130  39.960888
# 989                      Paris Baguette  ...    PA       19126  40.054636
# 997               The Independent Hotel  ...    PA       19107  39.947781
# 998  Fabio's Chicken Restaurant Takeout  ...    PA       19120  40.023288
# 999                      Federal Donuts  ...    PA       19123  39.964179
#
#      longitude  stars_y  review_count  is_open  \
# 1   -75.172753      5.0           144        0
# 3   -75.025080      4.0           181        1
# 5   -75.148131      4.0           273        0
# 13  -75.152139      3.5           367        0
# 16  -75.169532      3.5           290        1
# ..         ...      ...           ...      ...
# 985 -75.171213      4.0           651        1
# 989 -75.126113      4.0            32        1
# 997 -75.162146      3.5           123        0
# 998 -75.123764      4.5            14        1
# 999 -75.149424      4.0           321        1
#
#                                             attributes  \
# 1    {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 3    {'Caters': 'True', 'Ambience': '{'romantic': F...
# 5    {'BusinessParking': '{'garage': False, 'street...
# 13   {'RestaurantsReservations': 'True', 'BYOBCorka...
# 16   {'RestaurantsAttire': 'u'dressy'', 'Restaurant...
# ..                                                 ...
# 985  {'GoodForKids': 'True', 'HasTV': 'False', 'Bus...
# 989  {'BusinessParking': '{'garage': False, 'street...
# 997  {'BusinessAcceptsCreditCards': 'True', 'WiFi':...
# 998  {'HasTV': 'True', 'BusinessParking': '{'garage...
# 999  {'RestaurantsAttire': ''casual'', 'Restaurants...
#
#                                             categories  \
# 1    Active Life, Cycling Classes, Trainers, Gyms, ...
# 3                Halal, Pakistani, Restaurants, Indian
# 5           Mediterranean, Restaurants, Seafood, Greek
# 13                  Pizza, Restaurants, Italian, Salad
# 16   Wine Bars, Restaurants, Nightlife, Steakhouses...
# ..                                                 ...
# 985                 Italian, Pizza, Restaurants, Salad
# 989                                     Bakeries, Food
# 997  Hotels, Hotels & Travel, Event Planning & Serv...
# 998         Latin American, Restaurants, Chicken Wings
# 999  Restaurants, Donuts, Chicken Wings, Food, Coff...
#
#                                                  hours
# 1    {'Monday': '6:30-20:30', 'Tuesday': '6:30-20:3...
# 3    {'Tuesday': '11:0-21:0', 'Wednesday': '11:0-21...
# 5    {'Wednesday': '17:30-21:0', 'Thursday': '17:30...
# 13   {'Monday': '0:0-0:0', 'Tuesday': '11:30-21:0',...
# 16   {'Wednesday': '16:30-22:0', 'Thursday': '16:30...
# ..                                                 ...
# 985  {'Monday': '0:0-0:0', 'Tuesday': '11:30-21:0',...
# 989                                               None
# 997  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 998                                               None
# 999  {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...
#
# [186 rows x 22 columns]

# %%
# maximum chunk
output_file_path = 'file_6990.json'

# Load and print the contents of the file
with open(output_file_path, 'r') as infile:
    chunk_data1 = json.load(infile)
    print(chunk_data1)
# Out:
# [{'review_id': 'nN1EWUFB6G5vXLCGMnFpow', 'user_id': 'V5jfkywq-f4FpvDrUJMdfw', 'business_id': 'Zg83olSjsdXAhE5EEy5IcQ', 'stars': 5.0, 'useful': 1, 'funny': 0, 'cool': 0, 'text': 'This has been one of our favorite restaurants since before we moved to Tucson. For the price, the amount and quality of food received is pretty great. Most outstanding is the friendly, prompt service we have always received, even when the location is very busy. Definitely try the guacatony!!', 'date': '2014-07-19 05:25:16'}, {'review_id': 'gs6qP-N4oV-Fr8dpqowiIQ', 'user_id': 'l3YDgKIUhVLXKq8fYOR5NA', 'business_id': 'YGXh3EWuaZHWucYfyxQFUg', 'stars': 5.0, 'useful': 25, 'funny': 2, 'cool': 0, 'text': "I recently graduated from Galen and passed my NCLEX RN on the first attempt with around 90 questions. I was in the ADN program and will be starting the RN-BSN program within the next few weeks. \nYes- this school is expensive. It's a private school, which are always expensive. However, you get right into the program. No wait lists like at other schools. \nGalen is now FULLY ACCREDITED!! So no more using that as an excuse to not go!\nYes- it IS a tough program but guess what? I never failed a single class. You have to be dedicated and willing to give it your all and then some. If I can do it with two sons under the age of 7, so can you!\nI would 100% recommend this school to anyone wanting to become a nurse because the instructors truly want to see their students succeed. \nThe people leaving negative reviews must just be bitter because they didn't have what it takes to get through nursing school. Sorry, not sorry! \nHESI sucks but the NCLEX was a lot like the HESI and I think learning how to handle that stress early on helped me succeed with my NCLEX.", 'date': '2016-10-23 15:59:02'}, {'review_id': 'e0BM_gXdhJzswPSWEizItA', 'user_id': 'Kho08pWNfeGnRbZTnMKy3w', 'business_id': 'KoE-tbMBF33yHhuALmIezw', 'stars': 4.0, 'useful': 4, 'funny': 1, 'cool': 4, 'text': 'Spavia Day Spa was just the pampering that I needed. It is in the same shopping center as Home Goods but on the opposite end of the parking lot. They have many services here including waxing, massages, foot scrubs, facials and more. You can schedule an appointment online or by calling the spa. The process for booking online was easy and I received a confirmation and a reminder for the appointment before the date. They have a new client deal, which is $20 off of the service. They also have a membership where you can get one service a month for a discounted price. \n\nUpon arrival I was greeted and given a tablet to fill out new customer information which took about 5 minutes to do. Once I finished, I was shown the locker/changing room. They have a shower and bathroom inside this room as well. The lockers all have sandals and robes inside for you to change and get comfortable. After you are changed, there is a waiting area where your aesthetician or masseuse will come and get you for your appointment. The waiting area has a selection of tea and water as well. \n\nThe facial was really nice. In between the lotions and masks that are applied, you also get a massage on your arms and neck. Nothing was tingly or uncomfortable, which I appreciated. Taylor was super gentle, even with the extractions. \n\nI will definitely be back here, it was a great experience! Very professional staff and nice facilities.', 'date': '2019-04-09 15:52:12'}, {'review_id': 'n3JX4UuW_TY59a3wIG0tiQ', 'user_id': 'ooHF-vRzlkyN9UEVMKocAQ', 'business_id': '5rSg5FARufPsy_ACLLhy-g', 'stars': 4.0, 'useful': 14, 'funny': 4, 'cool': 11, 'text': "Chewing over which bakery in Tampa to visit for a small wedding cake was tiring day in and day out leading up to our flight. And the fear of disappointment of buying a stale, tasteless cake was real. \n\nWhen hubs found out his nephew and his new wife didn't plan on having a wedding cake (¯\\_(ツ)_/¯) after dinner, I came across a few that were closed for the Holiday season- but we certainly lucked out ...

# %%
import json
import pandas as pd

# Specify the file path of the output file (change to the desired file)
output_file_path = 'file_6990.json'

# Load chunk
with open(output_file_path, 'r') as infile:
    chunk_data = json.load(infile)

# Convert chunk to DataFrame (if it's a list of dictionaries)
chunk_df = pd.DataFrame(chunk_data)

# Assuming business_df is your business DataFrame
# Replace 'business_id' with the actual column name containing business IDs in your DataFrame
merged_chunk = pd.merge(chunk_df, business_df, on='business_id', how='left')

# Count ratings for each city in the chunk
city_counts = merged_chunk['city'].value_counts()

# Find the city with the most ratings
most_rated_city = city_counts.idxmax()
most_ratings_count = city_counts.max()

print(f"For the chunk in file {output_file_path}, the city with the most ratings is {most_rated_city} with {most_ratings_count} ratings.")
# Out:
# For the chunk in file file_6990.json, the city with the most ratings is Philadelphia with 39 ratings.

# %%
import json
import pandas as pd
# List to store results for each chunk
results_per_chunk = []

# Loop through all chunk files (file_01.json to file_1000.json)
for chunk_num in range(1, 1001):
    # Generate the file path for the current chunk
    output_file_path = f'file_{chunk_num:d}.json'

    # Load chunk
    with open(output_file_path, 'r') as infile:
        chunk_data = json.load(infile)

    # Convert chunk to DataFrame (if it's a list of dictionaries)
    chunk_df = pd.DataFrame(chunk_data)

    # Merge with business DataFrame
    merged_chunk = pd.merge(chunk_df, business_df, on='business_id', how='left')

    # Count ratings for each city in the chunk
    city_counts = merged_chunk['city'].value_counts()

    # Find the city with the most ratings
    most_rated_city = city_counts.idxmax()
    most_ratings_count = city_counts.max()

    # Store results for the current chunk
    results_per_chunk.append((output_file_path, most_rated_city, most_ratings_count))

# Display results for each chunk
for result in results_per_chunk:
    print(f"For the chunk in file {result[0]}, the city with the most ratings is {result[1]} with {result[2]} ratings.")
# Out:
# For the chunk in file file_1.json, the city with the most ratings is Philadelphia with 183 ratings.
# For the chunk in file file_2.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_3.json, the city with the most ratings is Philadelphia with 152 ratings.
# For the chunk in file file_4.json, the city with the most ratings is Philadelphia with 158 ratings.
# For the chunk in file file_5.json, the city with the most ratings is Philadelphia with 181 ratings.
# For the chunk in file file_6.json, the city with the most ratings is Philadelphia with 198 ratings.
# For the chunk in file file_7.json, the city with the most ratings is Philadelphia with 192 ratings.
# For the chunk in file file_8.json, the city with the most ratings is Philadelphia with 173 ratings.
# For the chunk in file file_9.json, the city with the most ratings is Philadelphia with 157 ratings.
# For the chunk in file file_10.json, the city with the most ratings is Philadelphia with 188 ratings.
# For the chunk in file file_11.json, the city with the most ratings is Philadelphia with 149 ratings.
# For the chunk in file file_12.json, the city with the most ratings is Philadelphia with 174 ratings.
# For the chunk in file file_13.json, the city with the most ratings is Philadelphia with 184 ratings.
# For the chunk in file file_14.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_15.json, the city with the most ratings is Philadelphia with 197 ratings.
# For the chunk in file file_16.json, the city with the most ratings is Philadelphia with 147 ratings.
# For the chunk in file file_17.json, the city with the most ratings is Philadelphia with 191 ratings.
# For the chunk in file file_18.json, the city with the most ratings is Philadelphia with 163 ratings.
# For the chunk in file file_19.json, the city with the most ratings is Philadelphia with 184 ratings.
# For the chunk in file file_20.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_21.json, the city with the most ratings is Philadelphia with 192 ratings.
# For the chunk in file file_22.json, the city with the most ratings is Philadelphia with 178 ratings.
# For the chunk in file file_23.json, the city with the most ratings is Philadelphia with 180 ratings.
# For the chunk in file file_24.json, the city with the most ratings is Philadelphia with 171 ratings.
# For the chunk in file file_25.json, the city with the most ratings is Philadelphia with 151 ratings.
# For the chunk in file file_26.json, the city with the most ratings is Philadelphia with 155 ratings.
# For the chunk in file file_27.json, the city with the most ratings is Philadelphia with 152 ratings.
# For the chunk in file file_28.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_29.json, the city with the most ratings is Philadelphia with 155 ratings.
# For the chunk in file file_30.json, the city with the most ratings is Philadelphia with 167 ratings.
# For the chunk in file file_31.json, the city with the most ratings is Philadelphia with 165 ratings.
# For the chunk in file file_32.json, the city with the most ratings is Philadelphia with 171 ratings.
# For the chunk in file file_33.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_34.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_35.json, the city with the most ratings is Philadelphia with 179 ratings.
# For the chunk in file file_36.json, the city with the most ratings is Philadelphia with 156 ratings.
# For the chunk in file file_37.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_38.json, the city with the most ratings is Philadelphia with 165 ratings.
# For the chunk in file file_39.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_40.json, the city with the most ratings is Philadelphia with 160 ratings.
# For the chunk in file file_41.json, the city with the most ratings is Philadelphia with 181 ratings.
# For the chunk in file file_42.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_43.json, the city with the most ratings is Philadelphia with 183 ratings.
# For the chunk in file file_44.json, the city with the most ratings is Philadelphia with 187 ratings.
# For the chunk in file file_45.json, the city with the most ratings is Philadelphia with 148 ratings.
# For the chunk in file file_46.json, the city with the most ratings is Philadelphia with 183 ratings.
# For the chunk in file file_47.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_48.json, the city with the most ratings is Philadelphia with 151 ratings.
# For the chunk in file file_49.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_50.json, the city with the most ratings is Philadelphia with 162 ratings.
# For the chunk in file file_51.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_52.json, the city with the most ratings is Philadelphia with 158 ratings.
# For the chunk in file file_53.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_54.json, the city with the most ratings is Philadelphia with 191 ratings.
# For the chunk in file file_55.json, the city with the most ratings is Philadelphia with 163 ratings.
# For the chunk in file file_56.json, the city with the most ratings is Philadelphia with 174 ratings.
# For the chunk in file file_57.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_58.json, the city with the most ratings is Philadelphia with 173 ratings.
# For the chunk in file file_59.json, the city with the most ratings is Philadelphia with 155 ratings.
# For the chunk in file file_60.json, the city with the most ratings is Philadelphia with 158 ratings.
# For the chunk in file file_61.json, the city with the most ratings is Philadelphia with 154 ratings.
# For the chunk in file file_62.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_63.json, the city with the most ratings is Philadelphia with 152 ratings.
# For the chunk in file file_64.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_65.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_66.json, the city with the most ratings is Philadelphia with 168 ratings.
# For the chunk in file file_67.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_68.json, the city with the most ratings is Philadelphia with 173 ratings.
# For the chunk in file file_69.json, the city with the most ratings is Philadelphia with 185 ratings.
# For the chunk in file file_70.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_71.json, the city with the most ratings is Philadelphia with 171 ratings.
# For the chunk in file file_72.json, the city with the most ratings is Philadelphia with 160 ratings.
# For the chunk in file file_73.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_74.json, the city with the most ratings is Philadelphia with 188 ratings.
# For the chunk in file file_75.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_76.json, the city with the most ratings is Philadelphia with 172 ratings.
# For the chunk in file file_77.json, the city with the most ratings is Philadelphia with 172 ratings.
# For the chunk in file file_78.json, the city with the most ratings is Philadelphia with 188 ratings.
# For the chunk in file file_79.json, the city with the most ratings is Philadelphia with 184 ratings.
# For the chunk in file file_80.json, the city with the most ratings is Philadelphia with 187 ratings.
# For the chunk in file file_81.json, the city with the most ratings is Philadelphia with 173 ratings.
# For the chunk in file file_82.json, the city with the most ratings is Philadelphia with 184 ratings.
# For the chunk in file file_83.json, the city with the most ratings is Philadelphia with 151 ratings.
# For the chunk in file file_84.json, the city with the most ratings is Philadelphia with 149 ratings.
# For the chunk in file file_85.json, the city with the most ratings is Philadelphia with 180 ratings.
# For the chunk in file file_86.json, the city with the most ratings is Philadelphia with 154 ratings.
# For the chunk in file file_87.json, the city with the most ratings is Philadelphia with 155 ratings.
# For the chunk in file file_88.json, the city with the most ratings is Philadelphia with 149 ratings.
# For the chunk in file file_89.json, the city with the most ratings is Philadelphia with 177 ratings.
# For the chunk in file file_90.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_91.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_92.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_93.json, the city with the most ratings is Philadelphia with 188 ratings.
# For the chunk in file file_94.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_95.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_96.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_97.json, the city with the most ratings is Philadelphia with 162 ratings.
# For the chunk in file file_98.json, the city with the most ratings is Philadelphia with 189 ratings.
# For the chunk in file file_99.json, the city with the most ratings is Philadelphia with 189 ratings.
# For the chunk in file file_100.json, the city with the most ratings is Philadelphia with 172 ratings.
# For the chunk in file file_101.json, the city with the most ratings is Philadelphia with 150 ratings.
# For the chunk in file file_102.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_103.json, the city with the most ratings is Philadelphia with 178 ratings.
# For the chunk in file file_104.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_105.json, the city with the most ratings is Philadelphia with 163 ratings.
# For the chunk in file file_106.json, the city with the most ratings is Philadelphia with 171 ratings.
# For the chunk in file file_107.json, the city with the most ratings is Philadelphia with 185 ratings.
# For the chunk in file file_108.json, the city with the most ratings is Philadelphia with 163 ratings.
# For the chunk in file file_109.json, the city with the most ratings is Philadelphia with 178 ratings.
# For the chunk in file file_110.json, the city with the most ratings is Philadelphia with 182 ratings.
# For the chunk in file file_111.json, the city with the most ratings is Philadelphia with 157 ratings.
# For the chunk in file file_112.json, the city with the most ratings is Philadelphia with 178 ratings.
# For the chunk in file file_113.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_114.json, the city with the most ratings is Philadelphia with 174 ratings.
# For the chunk in file file_115.json, the city with the most ratings is Philadelphia with 177 ratings.
# For the chunk in file file_116.json, the city with the most ratings is Philadelphia with 180 ratings.
# For the chunk in file file_117.json, the city with the most ratings is Philadelphia with 174 ratings.
# For the chunk in file file_118.json, the city with the most ratings is Philadelphia with 178 ratings.
# For the chunk in file file_119.json, the city with the most ratings is Philadelphia with 181 ratings.
# For the chunk in file file_120.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_121.json, the city with the most ratings is Philadelphia with 168 ratings.
# For the chunk in file file_122.json, the city with the most ratings is Philadelphia with 184 ratings.
# For the chunk in file file_123.json, the city with the most ratings is Philadelphia with 157 ratings.
# For the chunk in file file_124.json, the city with the most ratings is Philadelphia with 149 ratings.
# For the chunk in file file_125.json, the city with the most ratings is Philadelphia with 183 ratings.
# For the chunk in file file_126.json, the city with the most ratings is Philadelphia with 145 ratings.
# For the chunk in file file_127.json, the city with the most ratings is Philadelphia with 179 ratings.
# For the chunk in file file_128.json, the city with the most ratings is Philadelphia with 172 ratings.
# For the chunk in file file_129.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_130.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_131.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_132.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_133.json, the city with the most ratings is Philadelphia with 173 ratings.
# For the chunk in file file_134.json, the city with the most ratings is Philadelphia with 141 ratings.
# For the chunk in file file_135.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_136.json, the city with the most ratings is Philadelphia with 154 ratings.
# For the chunk in file file_137.json, the city with the most ratings is Philadelphia with 171 ratings.
# For the chunk in file file_138.json, the city with the most ratings is Philadelphia with 183 ratings.
# For the chunk in file file_139.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_140.json, the city with the most ratings is Philadelphia with 155 ratings.
# For the chunk in file file_141.json, the city with the most ratings is Philadelphia with 177 ratings.
# For the chunk in file file_142.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_143.json, the city with the most ratings is Philadelphia with 182 ratings.
# For the chunk in file file_144.json, the city with the most ratings is Philadelphia with 173 ratings.
# For the chunk in file file_145.json, the city with the most ratings is Philadelphia with 185 ratings.
# For the chunk in file file_146.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_147.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_148.json, the city with the most ratings is Philadelphia with 180 ratings.
# For the chunk in file file_149.json, the city with the most ratings is Philadelphia with 185 ratings.
# For the chunk in file file_150.json, the city with the most ratings is Philadelphia with 173 ratings.
# For the chunk in file file_151.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_152.json, the city with the most ratings is Philadelphia with 189 ratings.
# For the chunk in file file_153.json, the city with the most ratings is Philadelphia with 162 ratings.
# For the chunk in file file_154.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_155.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_156.json, the city with the most ratings is Philadelphia with 178 ratings.
# For the chunk in file file_157.json, the city with the most ratings is Philadelphia with 174 ratings.
# For the chunk in file file_158.json, the city with the most ratings is Philadelphia with 183 ratings.
# For the chunk in file file_159.json, the city with the most ratings is Philadelphia with 156 ratings.
# For the chunk in file file_160.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_161.json, the city with the most ratings is Philadelphia with 204 ratings.
# For the chunk in file file_162.json, the city with the most ratings is Philadelphia with 197 ratings.
# For the chunk in file file_163.json, the city with the most ratings is Philadelphia with 177 ratings.
# For the chunk in file file_164.json, the city with the most ratings is Philadelphia with 186 ratings.
# For the chunk in file file_165.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_166.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_167.json, the city with the most ratings is Philadelphia with 167 ratings.
# For the chunk in file file_168.json, the city with the most ratings is Philadelphia with 173 ratings.
# For the chunk in file file_169.json, the city with the most ratings is Philadelphia with 192 ratings.
# For the chunk in file file_170.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_171.json, the city with the most ratings is Philadelphia with 191 ratings.
# For the chunk in file file_172.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_173.json, the city with the most ratings is Philadelphia with 163 ratings.
# For the chunk in file file_174.json, the city with the most ratings is Philadelphia with 154 ratings.
# For the chunk in file file_175.json, the city with the most ratings is Philadelphia with 177 ratings.
# For the chunk in file file_176.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_177.json, the city with the most ratings is Philadelphia with 192 ratings.
# For the chunk in file file_178.json, the city with the most ratings is Philadelphia with 172 ratings.
# For the chunk in file file_179.json, the city with the most ratings is Philadelphia with 160 ratings.
# For the chunk in file file_180.json, the city with the most ratings is Philadelphia with 168 ratings.
# For the chunk in file file_181.json, the city with the most ratings is Philadelphia with 193 ratings.
# For the chunk in file file_182.json, the city with the most ratings is Philadelphia with 160 ratings.
# For the chunk in file file_183.json, the city with the most ratings is Philadelphia with 160 ratings.
# For the chunk in file file_184.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_185.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_186.json, the city with the most ratings is Philadelphia with 173 ratings.
# For the chunk in file file_187.json, the city with the most ratings is Philadelphia with 163 ratings.
# For the chunk in file file_188.json, the city with the most ratings is Philadelphia with 172 ratings.
# For the chunk in file file_189.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_190.json, the city with the most ratings is Philadelphia with 187 ratings.
# For the chunk in file file_191.json, the city with the most ratings is Philadelphia with 180 ratings.
# For the chunk in file file_192.json, the city with the most ratings is Philadelphia with 182 ratings.
# For the chunk in file file_193.json, the city with the most ratings is Philadelphia with 197 ratings.
# For the chunk in file file_194.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_195.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_196.json, the city with the most ratings is Philadelphia with 190 ratings.
# For the chunk in file file_197.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_198.json, the city with the most ratings is Philadelphia with 178 ratings.
# For the chunk in file file_199.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_200.json, the city with the most ratings is Philadelphia with 174 ratings.
# For the chunk in file file_201.json, the city with the most ratings is Philadelphia with 182 ratings.
# For the chunk in file file_202.json, the city with the most ratings is Philadelphia with 190 ratings.
# For the chunk in file file_203.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_204.json, the city with the most ratings is Philadelphia with 190 ratings.
# For the chunk in file file_205.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_206.json, the city with the most ratings is Philadelphia with 173 ratings.
# For the chunk in file file_207.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_208.json, the city with the most ratings is Philadelphia with 172 ratings.
# For the chunk in file file_209.json, the city with the most ratings is Philadelphia with 178 ratings.
# For the chunk in file file_210.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_211.json, the city with the most ratings is Philadelphia with 182 ratings.
# For the chunk in file file_212.json, the city with the most ratings is Philadelphia with 179 ratings.
# For the chunk in file file_213.json, the city with the most ratings is Philadelphia with 146 ratings.
# For the chunk in file file_214.json, the city with the most ratings is Philadelphia with 182 ratings.
# For the chunk in file file_215.json, the city with the most ratings is Philadelphia with 151 ratings.
# For the chunk in file file_216.json, the city with the most ratings is Philadelphia with 186 ratings.
# For the chunk in file file_217.json, the city with the most ratings is Philadelphia with 187 ratings.
# For the chunk in file file_218.json, the city with the most ratings is Philadelphia with 171 ratings.
# For the chunk in file file_219.json, the city with the most ratings is Philadelphia with 182 ratings.
# For the chunk in file file_220.json, the city with the most ratings is Philadelphia with 172 ratings.
# For the chunk in file file_221.json, the city with the most ratings is Philadelphia with 168 ratings.
# For the chunk in file file_222.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_223.json, the city with the most ratings is Philadelphia with 203 ratings.
# For the chunk in file file_224.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_225.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_226.json, the city with the most ratings is Philadelphia with 186 ratings.
# For the chunk in file file_227.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_228.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_229.json, the city with the most ratings is Philadelphia with 139 ratings.
# For the chunk in file file_230.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_231.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_232.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_233.json, the city with the most ratings is Philadelphia with 163 ratings.
# For the chunk in file file_234.json, the city with the most ratings is Philadelphia with 194 ratings.
# For the chunk in file file_235.json, the city with the most ratings is Philadelphia with 168 ratings.
# For the chunk in file file_236.json, the city with the most ratings is Philadelphia with 156 ratings.
# For the chunk in file file_237.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_238.json, the city with the most ratings is Philadelphia with 153 ratings.
# For the chunk in file file_239.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_240.json, the city with the most ratings is Philadelphia with 165 ratings.
# For the chunk in file file_241.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_242.json, the city with the most ratings is Philadelphia with 179 ratings.
# For the chunk in file file_243.json, the city with the most ratings is Philadelphia with 186 ratings.
# For the chunk in file file_244.json, the city with the most ratings is Philadelphia with 177 ratings.
# For the chunk in file file_245.json, the city with the most ratings is Philadelphia with 192 ratings.
# For the chunk in file file_246.json, the city with the most ratings is Philadelphia with 198 ratings.
# For the chunk in file file_247.json, the city with the most ratings is Philadelphia with 168 ratings.
# For the chunk in file file_248.json, the city with the most ratings is Philadelphia with 172 ratings.
# For the chunk in file file_249.json, the city with the most ratings is Philadelphia with 177 ratings.
# For the chunk in file file_250.json, the city with the most ratings is Philadelphia with 160 ratings.
# For the chunk in file file_251.json, the city with the most ratings is Philadelphia with 188 ratings.
# For the chunk in file file_252.json, the city with the most ratings is Philadelphia with 162 ratings.
# For the chunk in file file_253.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_254.json, the city with the most ratings is Philadelphia with 179 ratings.
# For the chunk in file file_255.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_256.json, the city with the most ratings is Philadelphia with 145 ratings.
# For the chunk in file file_257.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_258.json, the city with the most ratings is Philadelphia with 171 ratings.
# For the chunk in file file_259.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_260.json, the city with the most ratings is Philadelphia with 181 ratings.
# For the chunk in file file_261.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_262.json, the city with the most ratings is Philadelphia with 162 ratings.
# For the chunk in file file_263.json, the city with the most ratings is Philadelphia with 162 ratings.
# For the chunk in file file_264.json, the city with the most ratings is Philadelphia with 172 ratings.
# For the chunk in file file_265.json, the city with the most ratings is Philadelphia with 177 ratings.
# For the chunk in file file_266.json, the city with the most ratings is Philadelphia with 162 ratings.
# For the chunk in file file_267.json, the city with the most ratings is Philadelphia with 189 ratings.
# For the chunk in file file_268.json, the city with the most ratings is Philadelphia with 167 ratings.
# For the chunk in file file_269.json, the city with the most ratings is Philadelphia with 171 ratings.
# For the chunk in file file_270.json, the city with the most ratings is Philadelphia with 154 ratings.
# For the chunk in file file_271.json, the city with the most ratings is Philadelphia with 155 ratings.
# For the chunk in file file_272.json, the city with the most ratings is Philadelphia with 151 ratings.
# For the chunk in file file_273.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_274.json, the city with the most ratings is Philadelphia with 149 ratings.
# For the chunk in file file_275.json, the city with the most ratings is Philadelphia with 157 ratings.
# For the chunk in file file_276.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_277.json, the city with the most ratings is Philadelphia with 181 ratings.
# For the chunk in file file_278.json, the city with the most ratings is Philadelphia with 157 ratings.
# For the chunk in file file_279.json, the city with the most ratings is Philadelphia with 157 ratings.
# For the chunk in file file_280.json, the city with the most ratings is Philadelphia with 155 ratings.
# For the chunk in file file_281.json, the city with the most ratings is Philadelphia with 156 ratings.
# For the chunk in file file_282.json, the city with the most ratings is Philadelphia with 163 ratings.
# For the chunk in file file_283.json, the city with the most ratings is Philadelphia with 155 ratings.
# For the chunk in file file_284.json, the city with the most ratings is Philadelphia with 162 ratings.
# For the chunk in file file_285.json, the city with the most ratings is Philadelphia with 134 ratings.
# For the chunk in file file_286.json, the city with the most ratings is Philadelphia with 183 ratings.
# For the chunk in file file_287.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_288.json, the city with the most ratings is Philadelphia with 178 ratings.
# For the chunk in file file_289.json, the city with the most ratings is Philadelphia with 165 ratings.
# For the chunk in file file_290.json, the city with the most ratings is Philadelphia with 165 ratings.
# For the chunk in file file_291.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_292.json, the city with the most ratings is Philadelphia with 153 ratings.
# For the chunk in file file_293.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_294.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_295.json, the city with the most ratings is Philadelphia with 161 ratings.
# For the chunk in file file_296.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_297.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_298.json, the city with the most ratings is Philadelphia with 158 ratings.
# For the chunk in file file_299.json, the city with the most ratings is Philadelphia with 153 ratings.
# For the chunk in file file_300.json, the city with the most ratings is Philadelphia with 149 ratings.
# For the chunk in file file_301.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_302.json, the city with the most ratings is Philadelphia with 161 ratings.
# For the chunk in file file_303.json, the city with the most ratings is Philadelphia with 148 ratings.
# For the chunk in file file_304.json, the city with the most ratings is Philadelphia with 142 ratings.
# For the chunk in file file_305.json, the city with the most ratings is Philadelphia with 153 ratings.
# For the chunk in file file_306.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_307.json, the city with the most ratings is Philadelphia with 128 ratings.
# For the chunk in file file_308.json, the city with the most ratings is Philadelphia with 191 ratings.
# For the chunk in file file_309.json, the city with the most ratings is Philadelphia with 146 ratings.
# For the chunk in file file_310.json, the city with the most ratings is Philadelphia with 156 ratings.
# For the chunk in file file_311.json, the city with the most ratings is Philadelphia with 180 ratings.
# For the chunk in file file_312.json, the city with the most ratings is Philadelphia with 163 ratings.
# For the chunk in file file_313.json, the city with the most ratings is Philadelphia with 134 ratings.
# For the chunk in file file_314.json, the city with the most ratings is Philadelphia with 152 ratings.
# For the chunk in file file_315.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_316.json, the city with the most ratings is Philadelphia with 138 ratings.
# For the chunk in file file_317.json, the city with the most ratings is Philadelphia with 129 ratings.
# For the chunk in file file_318.json, the city with the most ratings is Philadelphia with 147 ratings.
# For the chunk in file file_319.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_320.json, the city with the most ratings is Philadelphia with 162 ratings.
# For the chunk in file file_321.json, the city with the most ratings is Philadelphia with 131 ratings.
# For the chunk in file file_322.json, the city with the most ratings is Philadelphia with 152 ratings.
# For the chunk in file file_323.json, the city with the most ratings is Philadelphia with 143 ratings.
# For the chunk in file file_324.json, the city with the most ratings is Philadelphia with 160 ratings.
# For the chunk in file file_325.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_326.json, the city with the most ratings is Philadelphia with 141 ratings.
# For the chunk in file file_327.json, the city with the most ratings is Philadelphia with 150 ratings.
# For the chunk in file file_328.json, the city with the most ratings is Philadelphia with 173 ratings.
# For the chunk in file file_329.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_330.json, the city with the most ratings is Philadelphia with 151 ratings.
# For the chunk in file file_331.json, the city with the most ratings is Philadelphia with 143 ratings.
# For the chunk in file file_332.json, the city with the most ratings is Philadelphia with 130 ratings.
# For the chunk in file file_333.json, the city with the most ratings is Philadelphia with 118 ratings.
# For the chunk in file file_334.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_335.json, the city with the most ratings is Philadelphia with 150 ratings.
# For the chunk in file file_336.json, the city with the most ratings is Philadelphia with 129 ratings.
# For the chunk in file file_337.json, the city with the most ratings is Philadelphia with 140 ratings.
# For the chunk in file file_338.json, the city with the most ratings is Philadelphia with 135 ratings.
# For the chunk in file file_339.json, the city with the most ratings is Philadelphia with 126 ratings.
# For the chunk in file file_340.json, the city with the most ratings is New Orleans with 139 ratings.
# For the chunk in file file_341.json, the city with the most ratings is Philadelphia with 141 ratings.
# For the chunk in file file_342.json, the city with the most ratings is Philadelphia with 147 ratings.
# For the chunk in file file_343.json, the city with the most ratings is Philadelphia with 155 ratings.
# For the chunk in file file_344.json, the city with the most ratings is Philadelphia with 135 ratings.
# For the chunk in file file_345.json, the city with the most ratings is Philadelphia with 145 ratings.
# For the chunk in file file_346.json, the city with the most ratings is Philadelphia with 127 ratings.
# For the chunk in file file_347.json, the city with the most ratings is Philadelphia with 142 ratings.
# For the chunk in file file_348.json, the city with the most ratings is Philadelphia with 146 ratings.
# For the chunk in file file_349.json, the city with the most ratings is Philadelphia with 148 ratings.
# For the chunk in file file_350.json, the city with the most ratings is Philadelphia with 147 ratings.
# For the chunk in file file_351.json, the city with the most ratings is Philadelphia with 137 ratings.
# For the chunk in file file_352.json, the city with the most ratings is Philadelphia with 147 ratings.
# For the chunk in file file_353.json, the city with the most ratings is Philadelphia with 131 ratings.
# For the chunk in file file_354.json, the city with the most ratings is Philadelphia with 139 ratings.
# For the chunk in file file_355.json, the city with the most ratings is Philadelphia with 150 ratings.
# For the chunk in file file_356.json, the city with the most ratings is Philadelphia with 147 ratings.
# For the chunk in file file_357.json, the city with the most ratings is Philadelphia with 125 ratings.
# For the chunk in file file_358.json, the city with the most ratings is Philadelphia with 132 ratings.
# For the chunk in file file_359.json, the city with the most ratings is New Orleans with 122 ratings.
# For the chunk in file file_360.json, the city with the most ratings is Philadelphia with 138 ratings.
# For the chunk in file file_361.json, the city with the most ratings is Philadelphia with 151 ratings.
# For the chunk in file file_362.json, the city with the most ratings is Philadelphia with 127 ratings.
# For the chunk in file file_363.json, the city with the most ratings is Philadelphia with 142 ratings.
# For the chunk in file file_364.json, the city with the most ratings is Philadelphia with 150 ratings.
# For the chunk in file file_365.json, the city with the most ratings is Philadelphia with 131 ratings.
# For the chunk in file file_366.json, the city with the most ratings is Philadelphia with 136 ratings.
# For the chunk in file file_367.json, the city with the most ratings is Philadelphia with 144 ratings.
# For the chunk in file file_368.json, the city with the most ratings is Philadelphia with 136 ratings.
# For the chunk in file file_369.json, the city with the most ratings is Philadelphia with 138 ratings.
# For the chunk in file file_370.json, the city with the most ratings is Philadelphia with 139 ratings.
# For the chunk in file file_371.json, the city with the most ratings is Philadelphia with 136 ratings.
# For the chunk in file file_372.json, the city with the most ratings is Philadelphia with 127 ratings.
# For the chunk in file file_373.json, the city with the most ratings is Philadelphia with 139 ratings.
# For the chunk in file file_374.json, the city with the most ratings is Philadelphia with 154 ratings.
# For the chunk in file file_375.json, the city with the most ratings is Philadelphia with 146 ratings.
# For the chunk in file file_376.json, the city with the most ratings is Philadelphia with 143 ratings.
# For the chunk in file file_377.json, the city with the most ratings is Philadelphia with 136 ratings.
# For the chunk in file file_378.json, the city with the most ratings is Philadelphia with 124 ratings.
# For the chunk in file file_379.json, the city with the most ratings is Philadelphia with 131 ratings.
# For the chunk in file file_380.json, the city with the most ratings is Philadelphia with 141 ratings.
# For the chunk in file file_381.json, the city with the most ratings is Philadelphia with 133 ratings.
# For the chunk in file file_382.json, the city with the most ratings is Philadelphia with 139 ratings.
# For the chunk in file file_383.json, the city with the most ratings is Philadelphia with 138 ratings.
# For the chunk in file file_384.json, the city with the most ratings is Philadelphia with 138 ratings.
# For the chunk in file file_385.json, the city with the most ratings is Philadelphia with 122 ratings.
# For the chunk in file file_386.json, the city with the most ratings is Philadelphia with 140 ratings.
# For the chunk in file file_387.json, the city with the most ratings is Philadelphia with 118 ratings.
# For the chunk in file file_388.json, the city with the most ratings is Philadelphia with 116 ratings.
# For the chunk in file file_389.json, the city with the most ratings is New Orleans with 115 ratings.
# For the chunk in file file_390.json, the city with the most ratings is Philadelphia with 137 ratings.
# For the chunk in file file_391.json, the city with the most ratings is Philadelphia with 124 ratings.
# For the chunk in file file_392.json, the city with the most ratings is Philadelphia with 122 ratings.
# For the chunk in file file_393.json, the city with the most ratings is Philadelphia with 121 ratings.
# For the chunk in file file_394.json, the city with the most ratings is Philadelphia with 127 ratings.
# For the chunk in file file_395.json, the city with the most ratings is Philadelphia with 135 ratings.
# For the chunk in file file_396.json, the city with the most ratings is Philadelphia with 136 ratings.
# For the chunk in file file_397.json, the city with the most ratings is Philadelphia with 144 ratings.
# For the chunk in file file_398.json, the city with the most ratings is New Orleans with 124 ratings.
# For the chunk in file file_399.json, the city with the most ratings is Philadelphia with 135 ratings.
# For the chunk in file file_400.json, the city with the most ratings is Philadelphia with 142 ratings.
# For the chunk in file file_401.json, the city with the most ratings is Philadelphia with 117 ratings.
# For the chunk in file file_402.json, the city with the most ratings is Philadelphia with 125 ratings.
# For the chunk in file file_403.json, the city with the most ratings is Philadelphia with 131 ratings.
# For the chunk in file file_404.json, the city with the most ratings is Philadelphia with 111 ratings.
# For the chunk in file file_405.json, the city with the most ratings is New Orleans with 106 ratings.
# For the chunk in file file_406.json, the city with the most ratings is Philadelphia with 124 ratings.
# For the chunk in file file_407.json, the city with the most ratings is Philadelphia with 118 ratings.
# For the chunk in file file_408.json, the city with the most ratings is Philadelphia with 151 ratings.
# For the chunk in file file_409.json, the city with the most ratings is Philadelphia with 139 ratings.
# For the chunk in file file_410.json, the city with the most ratings is Philadelphia with 119 ratings.
# For the chunk in file file_411.json, the city with the most ratings is New Orleans with 122 ratings.
# For the chunk in file file_412.json, the city with the most ratings is Philadelphia with 129 ratings.
# For the chunk in file file_413.json, the city with the most ratings is Philadelphia with 121 ratings.
# For the chunk in file file_414.json, the city with the most ratings is Philadelphia with 115 ratings.
# For the chunk in file file_415.json, the city with the most ratings is Philadelphia with 133 ratings.
# For the chunk in file file_416.json, the city with the most ratings is Philadelphia with 144 ratings.
# For the chunk in file file_417.json, the city with the most ratings is Philadelphia with 118 ratings.
# For the chunk in file file_418.json, the city with the most ratings is New Orleans with 115 ratings.
# For the chunk in file file_419.json, the city with the most ratings is Philadelphia with 133 ratings.
# For the chunk in file file_420.json, the city with the most ratings is Philadelphia with 118 ratings.
# For the chunk in file file_421.json, the city with the most ratings is Philadelphia with 133 ratings.
# For the chunk in file file_422.json, the city with the most ratings is Philadelphia with 114 ratings.
# For the chunk in file file_423.json, the city with the most ratings is Philadelphia with 116 ratings.
# For the chunk in file file_424.json, the city with the most ratings is Philadelphia with 116 ratings.
# For the chunk in file file_425.json, the city with the most ratings is Philadelphia with 128 ratings.
# For the chunk in file file_426.json, the city with the most ratings is New Orleans with 112 ratings.
# For the chunk in file file_427.json, the city with the most ratings is Philadelphia with 148 ratings.
# For the chunk in file file_428.json, the city with the most ratings is Philadelphia with 122 ratings.
# For the chunk in file file_429.json, the city with the most ratings is Philadelphia with 130 ratings.
# For the chunk in file file_430.json, the city with the most ratings is Philadelphia with 132 ratings.
# For the chunk in file file_431.json, the city with the most ratings is Philadelphia with 124 ratings.
# For the chunk in file file_432.json, the city with the most ratings is Philadelphia with 107 ratings.
# For the chunk in file file_433.json, the city with the most ratings is Philadelphia with 136 ratings.
# For the chunk in file file_434.json, the city with the most ratings is Philadelphia with 114 ratings.
# For the chunk in file file_435.json, the city with the most ratings is Philadelphia with 128 ratings.
# For the chunk in file file_436.json, the city with the most ratings is Philadelphia with 116 ratings.
# For the chunk in file file_437.json, the city with the most ratings is Philadelphia with 117 ratings.
# For the chunk in file file_438.json, the city with the most ratings is Philadelphia with 113 ratings.
# For the chunk in file file_439.json, the city with the most ratings is New Orleans with 98 ratings.
# For the chunk in file file_440.json, the city with the most ratings is Philadelphia with 121 ratings.
# For the chunk in file file_441.json, the city with the most ratings is Philadelphia with 110 ratings.
# For the chunk in file file_442.json, the city with the most ratings is Philadelphia with 118 ratings.
# For the chunk in file file_443.json, the city with the most ratings is Philadelphia with 120 ratings.
# For the chunk in file file_444.json, the city with the most ratings is Philadelphia with 116 ratings.
# For the chunk in file file_445.json, the city with the most ratings is Philadelphia with 119 ratings.
# For the chunk in file file_446.json, the city with the most ratings is Philadelphia with 127 ratings.
# For the chunk in file file_447.json, the city with the most ratings is Philadelphia with 125 ratings.
# For the chunk in file file_448.json, the city with the most ratings is Philadelphia with 109 ratings.
# For the chunk in file file_449.json, the city with the most ratings is Philadelphia with 123 ratings.
# For the chunk in file file_450.json, the city with the most ratings is Philadelphia with 106 ratings.
# For the chunk in file file_451.json, the city with the most ratings is Philadelphia with 121 ratings.
# For the chunk in file file_452.json, the city with the most ratings is Philadelphia with 117 ratings.
# For the chunk in file file_453.json, the city with the most ratings is Philadelphia with 111 ratings.
# For the chunk in file file_454.json, the city with the most ratings is Philadelphia with 104 ratings.
# For the chunk in file file_455.json, the city with the most ratings is Philadelphia with 114 ratings.
# For the chunk in file file_456.json, the city with the most ratings is Philadelphia with 106 ratings.
# For the chunk in file file_457.json, the city with the most ratings is Philadelphia with 141 ratings.
# For the chunk in file file_458.json, the city with the most ratings is Philadelphia with 120 ratings.
# For the chunk in file file_459.json, the city with the most ratings is Philadelphia with 127 ratings.
# For the chunk in file file_460.json, the city with the most ratings is Philadelphia with 114 ratings.
# For the chunk in file file_461.json, the city with the most ratings is Philadelphia with 125 ratings.
# For the chunk in file file_462.json, the city with the most ratings is Philadelphia with 108 ratings.
# For the chunk in file file_463.json, the city with the most ratings is Philadelphia with 128 ratings.
# For the chunk in file file_464.json, the city with the most ratings is Philadelphia with 111 ratings.
# For the chunk in file file_465.json, the city with the most ratings is Philadelphia with 125 ratings.
# For the chunk in file file_466.json, the city with the most ratings is Philadelphia with 123 ratings.
# For the chunk in file file_467.json, the city with the most ratings is Philadelphia with 124 ratings.
# For the chunk in file file_468.json, the city with the most ratings is Philadelphia with 101 ratings.
# For the chunk in file file_469.json, the city with the most ratings is Philadelphia with 122 ratings.
# For the chunk in file file_470.json, the city with the most ratings is Philadelphia with 103 ratings.
# For the chunk in file file_471.json, the city with the most ratings is Philadelphia with 129 ratings.
# ...
# For the chunk in file file_845.json, the city with the most ratings is Philadelphia with 185 ratings.
# For the chunk in file file_846.json, the city with the most ratings is Philadelphia with 182 ratings.
# For the chunk in file file_847.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_848.json, the city with the most ratings is Philadelphia with 160 ratings.
# For the chunk in file file_849.json, the city with the most ratings is Philadelphia with 173 ratings.
# For the chunk in file file_850.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_851.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_852.json, the city with the most ratings is Philadelphia with 184 ratings.
# For the chunk in file file_853.json, the city with the most ratings is Philadelphia with 208 ratings.
# For the chunk in file file_854.json, the city with the most ratings is Philadelphia with 146 ratings.
# For the chunk in file file_855.json, the city with the most ratings is Philadelphia with 191 ratings.
# For the chunk in file file_856.json, the city with the most ratings is Philadelphia with 171 ratings.
# For the chunk in file file_857.json, the city with the most ratings is Philadelphia with 189 ratings.
# For the chunk in file file_858.json, the city with the most ratings is Philadelphia with 179 ratings.
# For the chunk in file file_859.json, the city with the most ratings is Philadelphia with 186 ratings.
# For the chunk in file file_860.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_861.json, the city with the most ratings is Philadelphia with 181 ratings.
# For the chunk in file file_862.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_863.json, the city with the most ratings is Philadelphia with 188 ratings.
# For the chunk in file file_864.json, the city with the most ratings is Philadelphia with 177 ratings.
# For the chunk in file file_865.json, the city with the most ratings is Philadelphia with 168 ratings.
# For the chunk in file file_866.json, the city with the most ratings is Philadelphia with 200 ratings.
# For the chunk in file file_867.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_868.json, the city with the most ratings is Philadelphia with 167 ratings.
# For the chunk in file file_869.json, the city with the most ratings is Philadelphia with 154 ratings.
# For the chunk in file file_870.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_871.json, the city with the most ratings is Philadelphia with 196 ratings.
# For the chunk in file file_872.json, the city with the most ratings is Philadelphia with 160 ratings.
# For the chunk in file file_873.json, the city with the most ratings is Philadelphia with 173 ratings.
# For the chunk in file file_874.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_875.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_876.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_877.json, the city with the most ratings is Philadelphia with 171 ratings.
# For the chunk in file file_878.json, the city with the most ratings is Philadelphia with 186 ratings.
# For the chunk in file file_879.json, the city with the most ratings is Philadelphia with 188 ratings.
# For the chunk in file file_880.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_881.json, the city with the most ratings is Philadelphia with 178 ratings.
# For the chunk in file file_882.json, the city with the most ratings is Philadelphia with 162 ratings.
# For the chunk in file file_883.json, the city with the most ratings is Philadelphia with 162 ratings.
# For the chunk in file file_884.json, the city with the most ratings is Philadelphia with 173 ratings.
# For the chunk in file file_885.json, the city with the most ratings is Philadelphia with 167 ratings.
# For the chunk in file file_886.json, the city with the most ratings is Philadelphia with 183 ratings.
# For the chunk in file file_887.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_888.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_889.json, the city with the most ratings is Philadelphia with 195 ratings.
# For the chunk in file file_890.json, the city with the most ratings is Philadelphia with 168 ratings.
# For the chunk in file file_891.json, the city with the most ratings is Philadelphia with 205 ratings.
# For the chunk in file file_892.json, the city with the most ratings is Philadelphia with 183 ratings.
# For the chunk in file file_893.json, the city with the most ratings is Philadelphia with 178 ratings.
# For the chunk in file file_894.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_895.json, the city with the most ratings is Philadelphia with 180 ratings.
# For the chunk in file file_896.json, the city with the most ratings is Philadelphia with 204 ratings.
# For the chunk in file file_897.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_898.json, the city with the most ratings is Philadelphia with 193 ratings.
# For the chunk in file file_899.json, the city with the most ratings is Philadelphia with 153 ratings.
# For the chunk in file file_900.json, the city with the most ratings is Philadelphia with 168 ratings.
# For the chunk in file file_901.json, the city with the most ratings is Philadelphia with 167 ratings.
# For the chunk in file file_902.json, the city with the most ratings is Philadelphia with 178 ratings.
# For the chunk in file file_903.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_904.json, the city with the most ratings is Philadelphia with 180 ratings.
# For the chunk in file file_905.json, the city with the most ratings is Philadelphia with 167 ratings.
# For the chunk in file file_906.json, the city with the most ratings is Philadelphia with 171 ratings.
# For the chunk in file file_907.json, the city with the most ratings is Philadelphia with 189 ratings.
# For the chunk in file file_908.json, the city with the most ratings is Philadelphia with 178 ratings.
# For the chunk in file file_909.json, the city with the most ratings is Philadelphia with 179 ratings.
# For the chunk in file file_910.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_911.json, the city with the most ratings is Philadelphia with 187 ratings.
# For the chunk in file file_912.json, the city with the most ratings is Philadelphia with 168 ratings.
# For the chunk in file file_913.json, the city with the most ratings is Philadelphia with 185 ratings.
# For the chunk in file file_914.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_915.json, the city with the most ratings is Philadelphia with 181 ratings.
# For the chunk in file file_916.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_917.json, the city with the most ratings is Philadelphia with 187 ratings.
# For the chunk in file file_918.json, the city with the most ratings is Philadelphia with 171 ratings.
# For the chunk in file file_919.json, the city with the most ratings is Philadelphia with 161 ratings.
# For the chunk in file file_920.json, the city with the most ratings is Philadelphia with 190 ratings.
# For the chunk in file file_921.json, the city with the most ratings is Philadelphia with 178 ratings.
# For the chunk in file file_922.json, the city with the most ratings is Philadelphia with 165 ratings.
# For the chunk in file file_923.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_924.json, the city with the most ratings is Philadelphia with 174 ratings.
# For the chunk in file file_925.json, the city with the most ratings is Philadelphia with 192 ratings.
# For the chunk in file file_926.json, the city with the most ratings is Philadelphia with 164 ratings.
# For the chunk in file file_927.json, the city with the most ratings is Philadelphia with 167 ratings.
# For the chunk in file file_928.json, the city with the most ratings is Philadelphia with 189 ratings.
# For the chunk in file file_929.json, the city with the most ratings is Philadelphia with 153 ratings.
# For the chunk in file file_930.json, the city with the most ratings is Philadelphia with 163 ratings.
# For the chunk in file file_931.json, the city with the most ratings is Philadelphia with 174 ratings.
# For the chunk in file file_932.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_933.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_934.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_935.json, the city with the most ratings is Philadelphia with 172 ratings.
# For the chunk in file file_936.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_937.json, the city with the most ratings is Philadelphia with 187 ratings.
# For the chunk in file file_938.json, the city with the most ratings is Philadelphia with 194 ratings.
# For the chunk in file file_939.json, the city with the most ratings is Philadelphia with 171 ratings.
# For the chunk in file file_940.json, the city with the most ratings is Philadelphia with 186 ratings.
# For the chunk in file file_941.json, the city with the most ratings is Philadelphia with 181 ratings.
# For the chunk in file file_942.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_943.json, the city with the most ratings is Philadelphia with 180 ratings.
# For the chunk in file file_944.json, the city with the most ratings is Philadelphia with 148 ratings.
# For the chunk in file file_945.json, the city with the most ratings is Philadelphia with 199 ratings.
# For the chunk in file file_946.json, the city with the most ratings is Philadelphia with 185 ratings.
# For the chunk in file file_947.json, the city with the most ratings is Philadelphia with 184 ratings.
# For the chunk in file file_948.json, the city with the most ratings is Philadelphia with 183 ratings.
# For the chunk in file file_949.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_950.json, the city with the most ratings is Philadelphia with 168 ratings.
# For the chunk in file file_951.json, the city with the most ratings is Philadelphia with 174 ratings.
# For the chunk in file file_952.json, the city with the most ratings is Philadelphia with 169 ratings.
# For the chunk in file file_953.json, the city with the most ratings is Philadelphia with 187 ratings.
# For the chunk in file file_954.json, the city with the most ratings is Philadelphia with 161 ratings.
# For the chunk in file file_955.json, the city with the most ratings is Philadelphia with 159 ratings.
# For the chunk in file file_956.json, the city with the most ratings is Philadelphia with 167 ratings.
# For the chunk in file file_957.json, the city with the most ratings is Philadelphia with 176 ratings.
# For the chunk in file file_958.json, the city with the most ratings is Philadelphia with 219 ratings.
# For the chunk in file file_959.json, the city with the most ratings is Philadelphia with 186 ratings.
# For the chunk in file file_960.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_961.json, the city with the most ratings is Philadelphia with 188 ratings.
# For the chunk in file file_962.json, the city with the most ratings is Philadelphia with 174 ratings.
# For the chunk in file file_963.json, the city with the most ratings is Philadelphia with 191 ratings.
# For the chunk in file file_964.json, the city with the most ratings is Philadelphia with 181 ratings.
# For the chunk in file file_965.json, the city with the most ratings is Philadelphia with 166 ratings.
# For the chunk in file file_966.json, the city with the most ratings is Philadelphia with 165 ratings.
# For the chunk in file file_967.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_968.json, the city with the most ratings is Philadelphia with 204 ratings.
# For the chunk in file file_969.json, the city with the most ratings is Philadelphia with 184 ratings.
# For the chunk in file file_970.json, the city with the most ratings is Philadelphia with 179 ratings.
# For the chunk in file file_971.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_972.json, the city with the most ratings is Philadelphia with 182 ratings.
# For the chunk in file file_973.json, the city with the most ratings is Philadelphia with 185 ratings.
# For the chunk in file file_974.json, the city with the most ratings is Philadelphia with 180 ratings.
# For the chunk in file file_975.json, the city with the most ratings is Philadelphia with 183 ratings.
# For the chunk in file file_976.json, the city with the most ratings is Philadelphia with 181 ratings.
# For the chunk in file file_977.json, the city with the most ratings is Philadelphia with 185 ratings.
# For the chunk in file file_978.json, the city with the most ratings is Philadelphia with 190 ratings.
# For the chunk in file file_979.json, the city with the most ratings is Philadelphia with 191 ratings.
# For the chunk in file file_980.json, the city with the most ratings is Philadelphia with 194 ratings.
# For the chunk in file file_981.json, the city with the most ratings is Philadelphia with 188 ratings.
# For the chunk in file file_982.json, the city with the most ratings is Philadelphia with 188 ratings.
# For the chunk in file file_983.json, the city with the most ratings is Philadelphia with 195 ratings.
# For the chunk in file file_984.json, the city with the most ratings is Philadelphia with 175 ratings.
# For the chunk in file file_985.json, the city with the most ratings is Philadelphia with 188 ratings.
# For the chunk in file file_986.json, the city with the most ratings is Philadelphia with 173 ratings.
# For the chunk in file file_987.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_988.json, the city with the most ratings is Philadelphia with 222 ratings.
# For the chunk in file file_989.json, the city with the most ratings is Philadelphia with 171 ratings.
# For the chunk in file file_990.json, the city with the most ratings is Philadelphia with 182 ratings.
# For the chunk in file file_991.json, the city with the most ratings is Philadelphia with 182 ratings.
# For the chunk in file file_992.json, the city with the most ratings is Philadelphia with 185 ratings.
# For the chunk in file file_993.json, the city with the most ratings is Philadelphia with 163 ratings.
# For the chunk in file file_994.json, the city with the most ratings is Philadelphia with 168 ratings.
# For the chunk in file file_995.json, the city with the most ratings is Philadelphia with 185 ratings.
# For the chunk in file file_996.json, the city with the most ratings is Philadelphia with 170 ratings.
# For the chunk in file file_997.json, the city with the most ratings is Philadelphia with 183 ratings.
# For the chunk in file file_998.json, the city with the most ratings is Philadelphia with 182 ratings.
# For the chunk in file file_999.json, the city with the most ratings is Philadelphia with 163 ratings.
# For the chunk in file file_1000.json, the city with the most ratings is Philadelphia with 169 ratings.

# %%
merged_dfs = []

# Loop through all chunk files (file_01.json to file_1000.json)
for chunk_num in range(1, 6990):
    # Generate the file path for the current chunk
    output_file_path = f'file_{chunk_num:d}.json'

    # Load chunk
    with open(output_file_path, 'r') as infile:
        chunk_data = json.load(infile)

    # Convert chunk to DataFrame (if it's a list of dictionaries)
    chunk_df = pd.DataFrame(chunk_data)

    # Merge with business DataFrame
    merged_chunk = pd.merge(chunk_df, business_df, on='business_id', how='left')

    # Filter for rows where the city is 'Philadelphia'
    philadelphia_data = merged_chunk[merged_chunk['city'] == 'Philadelphia']

    # Append to the list
    merged_dfs.append(philadelphia_data)

# Concatenate all DataFrames in the list into a single DataFrame
final_merged_df = pd.concat(merged_dfs, ignore_index=True)

# Display the final merged DataFrame
final_merged_df
# Out:
#                      review_id                 user_id  \
# 0       2fA_8TK24PULHnFz4CE_JA  B7d4_zvYzjE1D-E2fSw9LA
# 1       D9Toy0Ve0j77tp2iHVW3HA  92KVnXQL9KH5A_aX-lnEdA
# 2       M7AGmOpm0PzSdSmP8dA_3A  OXmETnil1QAshKPioX8qjg
# 3       gIUerFG2uz_nJo4lpqKgJA  toOnaUdZoYbdGU6MP8Gu9g
# 4       QyvqHQzpNS1Zdiy88BIb3w  YHzVud8gFNn1MLAKsek_Iw
# ...                        ...                     ...
# 967322  dZR89NmQJR3VtCw3Q2MXww  Y0MjA5a67vfzttu7TENETQ
# 967323  BOTpJP2dh8pej0xZ-w9LdQ  StyRL27Qj1Cy-yRBFuLSAQ
# 967324  fb_xKUoJb-A2wWTSmFndfg  pGmbV55YLG54t8r1W4F3xg
# 967325  2K_TCx1zNTbYjUc_B4_wZA  IU21A35P9AOaG8sgeuCTbA
# 967326  kEORLv45xKdNkNTTUdqpUA  0dxR_Q8PCOOWNkfpvI4t3w
#
#                    business_id  stars_x  useful  funny  cool  \
# 0       gGyqnAlpFrka_qzpO7j4lQ      2.0       1      5     2
# 1       NeY1bH6IKJxnn4YAixibsQ      2.0       0      0     0
# 2       qjGS_7iaQDpbVhS6W8qkHQ      5.0       2      0     0
# 3       lkPAmyZDva5Bt4EaqzjS8g      5.0       1      0     0
# 4       dfKF-oAUf3yjnD0WBYDyZQ      5.0       0      0     0
# ...                        ...      ...     ...    ...   ...
# 967322  QGYzYUMsQe6k7__LD91E5w      5.0       1      0     1
# 967323  JHRlwxxKY0JJcU97rJ-Bug      4.0       1      0     1
# 967324  -1B9pP_CrRBJYPICE5WbRA      5.0       1      0     1
# 967325  xTCSNzu7387VHOPO7DkEzA      3.0       0      0     0
# 967326  eLi0bpsDoWQkBhJX1d46tg      5.0       1      0     0
#
#                                                      text  \
# 0       To the other reviewers \nYou are reviewing the...
# 1       Good menu, solid ingredients, but these folks ...
# 2       This place is absolutely amazing. A cute littl...
# 3       In love with my haircut! Very reasonable price...
# 4       We tried these at the Collingswood Art Festiva...
# ...                                                   ...
# 967322  Really good bahn mi sandwiches in Chinatown!\n...
# 967323  A good place for some quiet happy hour drinks....
# 967324  Spice 28 is a great happy hour option in the h...
# 967325  Yes I am a fan...There are many overwhelming p...
# 967326  I'm writing this review because I think Fergie...
#
#                        date                                            name  \
# 0       2009-05-19 19:12:28                              Citizens Bank Park
# 1       2014-04-19 19:45:40                                            Cosi
# 2       2016-01-17 06:11:00                         The Sweet Life Bakeshop
# 3       2018-03-15 21:20:03                              Kevin's Hair Salon
# 4       2013-08-18 17:41:05                            The Cow and The Curd
# ...                     ...                                             ...
# 967322  2022-01-17 14:36:56                          QT Vietnamese Sandwich
# 967323  2019-12-31 23:01:45  Cuba Libre Restaurant & Rum Bar - Philadelphia
# 967324  2021-11-08 15:15:45                                        Spice 28
# 967325  2013-12-30 11:21:29          The Notary Hotel, Autograph Collection
# 967326  2019-05-02 15:23:50                                    Fergie's Pub
#
#         ... state postal_code   latitude  longitude  stars_y  review_count  \
# 0       ...    PA       19176  39.905993 -75.166640      4.5           515
# 1       ...    PA       19104  39.953671 -75.194957      2.5           115
# 2       ...    PA       19147  39.942203 -75.155223      5.0           316
# 3       ...    PA       19147  39.934859 -75.153675      3.0            15
# 4       ...    PA       19149  40.048754 -75.062078      4.0           117
# ...     ...   ...         ...        ...        ...      ...           ...
# 967322  ...    PA       19107  39.953229 -75.156582      4.5           538
# 967323  ...    PA       19106  39.949589 -75.143910      3.5          1195
# 967324  ...    PA       19107  39.950352 -75.161583      4.0           822
# 967325  ...    PA       19107  39.953083 -75.162187      3.5           286
# 967326  ...    PA       19107  39.949596 -75.161128      3.5           286
#
#         is_open                                         attributes  \
# 0             1  {'GoodForKids': 'True', 'DogsAllowed': 'False'...
# 1             0  {'RestaurantsGoodForGroups': 'True', 'Business...
# 2             1  {'BusinessAcceptsBitcoin': 'False', 'NoiseLeve...
# 3             1  {'ByAppointmentOnly': 'False', 'RestaurantsPri...
# 4             1  {'BusinessParking': '{'garage': False, 'street...
# ...         ...                                                ...
# 967322        1  {'RestaurantsPriceRange2': '1', 'BikeParking':...
# 967323        1  {'Corkage': 'False', 'RestaurantsTakeOut': 'Tr...
# 967324        1  {'RestaurantsGoodForGroups': 'True', 'WiFi': '...
# 967325        1  {'BusinessAcceptsCreditCards': 'True', 'DogsAl...
# 967326        1  {'RestaurantsDelivery': 'False', 'GoodForKids'...
#
#                                                categories  \
# 0       Active Life, Baseball Fields, Stadiums & Arena...
# 1             Coffee & Tea, Restaurants, Sandwiches, Food
# 2                      Food, Cupcakes, Desserts, Bakeries
# 3       Beauty & Spas, Nail Salons, Hair Salons, Hair ...
# 4                                       Food, Food Trucks
# ...                                                   ...
# 967322  Vietnamese, Restaurants, Sandwiches, Specialty...
# 967323  Nightlife, Cuban, Breakfast & Brunch, Latin Am...
# 967324  Asian Fusion, Restaurants, American (New), Tha...
# 967325  Caterers, Hotels & Travel, Event Planning & Se...
# 967326  Event Planning & Services, Bars, Pubs, Nightli...
#
#                                                     hours
# 0                                                    None
# 1       {'Monday': '0:0-0:0', 'Tuesday': '7:0-22:0', '...
# 2       {'Monday': '0:0-0:0', 'Tuesday': '11:0-18:30',...
# 3       {'Monday': '0:0-0:0', 'Tuesday': '10:30-19:30'...
# 4                                                    None
# ...                                                   ...
# 967322  {'Monday': '0:0-0:0', 'Tuesday': '9:0-19:0', '...
# 967323  {'Monday': '0:0-0:0', 'Tuesday': '16:0-22:0', ...
# 967324  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:30...
# 967325  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 967326  {'Monday': '12:0-2:0', 'Tuesday': '12:0-2:0', ...
#
# [967327 rows x 22 columns]

# %%
final_merged_df.columns
# Out:
# Index(['review_id', 'user_id', 'business_id', 'stars_x', 'useful', 'funny',
#        'cool', 'text', 'date', 'name', 'address', 'city', 'state',
#        'postal_code', 'latitude', 'longitude', 'stars_y', 'review_count',
#        'is_open', 'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
ff = final_merged_df['date'].astype(str).str[:4]
pd.to_numeric(ff,errors = 'coerce').describe()
# Out:
# count    967327.000000
# mean       2015.472440
# std           3.380668
# min        2005.000000
# 25%        2013.000000
# 50%        2016.000000
# 75%        2018.000000
# max        2022.000000
# Name: date, dtype: float64

# %%
print(final_merged_df.describe())
# Out:
#              stars_x         useful          funny           cool  \
# count  967327.000000  967327.000000  967327.000000  967327.000000
# mean        3.785662       1.297065       0.404677       0.574951
# std         1.388231       3.018900       1.703322       2.098384
# min         1.000000       0.000000       0.000000       0.000000
# 25%         3.000000       0.000000       0.000000       0.000000
# 50%         4.000000       0.000000       0.000000       0.000000
# 75%         5.000000       2.000000       0.000000       1.000000
# max         5.000000     320.000000     284.000000     192.000000
#
#             latitude      longitude        stars_y   review_count  \
# count  967327.000000  967327.000000  967327.000000  967327.000000
# mean       39.962187     -75.160156       3.783088     486.901473
# std         0.038023       0.038714       0.702474     775.737225
# min        39.864924     -75.651673       1.000000       5.000000
# 25%        39.947327     -75.172563       3.500000      70.000000
# 50%        39.951095     -75.161924       4.000000     214.000000
# 75%        39.962601     -75.149453       4.000000     550.000000
# max        40.247267     -74.893799       5.000000    5721.000000
#
#              is_open
# count  967327.000000
# mean        0.769076
# std         0.421424
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
print(final_merged_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 967327 entries, 0 to 967326
# Data columns (total 22 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   review_id     967327 non-null  object
#  1   user_id       967327 non-null  object
#  2   business_id   967327 non-null  object
#  3   stars_x       967327 non-null  float64
#  4   useful        967327 non-null  int64
#  5   funny         967327 non-null  int64
#  6   cool          967327 non-null  int64
#  7   text          967327 non-null  object
#  8   date          967327 non-null  object
#  9   name          967327 non-null  object
#  10  address       967327 non-null  object
#  11  city          967327 non-null  object
#  12  state         967327 non-null  object
#  13  postal_code   967327 non-null  object
#  14  latitude      967327 non-null  float64
#  15  longitude     967327 non-null  float64
#  16  stars_y       967327 non-null  float64
#  17  review_count  967327 non-null  int64
#  18  is_open       967327 non-null  int64
#  19  attributes    945353 non-null  object
#  20  categories    967264 non-null  object
#  21  hours         910111 non-null  object
# dtypes: float64(4), int64(5), object(13)
# memory usage: 162.4+ MB
# None

# %%
print(final_merged_df.isnull().sum())
# Out:
# review_id           0
# user_id             0
# business_id         0
# stars_x             0
# useful              0
# funny               0
# cool                0
# text                0
# date                0
# name                0
# address             0
# city                0
# state               0
# postal_code         0
# latitude            0
# longitude           0
# stars_y             0
# review_count        0
# is_open             0
# attributes      21974
# categories         63
# hours           57216
# dtype: int64

# %%
for column in final_merged_df.columns:
    unique_values = final_merged_df[column].nunique()
    print(f"Unique values in {column}: {unique_values}")
# Out:
# Unique values in review_id: 967327
# Unique values in user_id: 279827
# Unique values in business_id: 14569
# Unique values in stars_x: 5
# Unique values in useful: 138
# Unique values in funny: 106
# Unique values in cool: 121
# Unique values in text: 965577
# Unique values in date: 965057
# Unique values in name: 12783
# Unique values in address: 10883
# Unique values in city: 1
# Unique values in state: 2
# Unique values in postal_code: 90
# Unique values in latitude: 12817
# Unique values in longitude: 12378
# Unique values in stars_y: 9
# Unique values in review_count: 680
# Unique values in is_open: 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [79], in <cell line: 1>()
#       1 for column in final_merged_df.columns:
# ----> 2     unique_values = final_merged_df[column].nunique()
#       3     print(f"Unique values in {column}: {unique_values}")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/base.py:1027, in IndexOpsMixin.nunique(self, dropna)
#     993 def nunique(self, dropna: bool = True) -> int:
#     994     """
#     995     Return number of unique elements in the object.
#     996
#    (...)
#    1025     4
#    1026     """
# -> 1027     uniqs = self.unique()
#    1028     if dropna:
#    1029         uniqs = remove_na_arraylike(uniqs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:2088, in Series.unique(self)
#    2030 def unique(self) -> ArrayLike:
#    2031     """
#    2032     Return unique values of Series object.
#    2033
#    (...)
#    2086     Categories (3, object): ['a' < 'b' < 'c']
#    2087     """
# -> 2088     return super().unique()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/base.py:989, in IndexOpsMixin.unique(self)
#     987             result = np.asarray(result)
#     988 else:
# --> 989     result = unique1d(values)
#     991 return result
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/algorithms.py:440, in unique(values)
#     437 htable, values = _get_hashtable_algo(values)
#     439 table = htable(len(values))
# --> 440 uniques = table.unique(values)
#     441 uniques = _reconstruct_data(uniques, original.dtype, original)
#     442 return uniques
#
# File pandas/_libs/hashtable_class_helper.pxi:5361, in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# File pandas/_libs/hashtable_class_helper.pxi:5310, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'dict'

# %%
final_merged_df['funny']
# Out:
# 0         5
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 967322    0
# 967323    0
# 967324    0
# 967325    0
# 967326    0
# Name: funny, Length: 967327, dtype: int64

# %%
import matplotlib.pyplot as plt

numerical_columns = final_merged_df.select_dtypes(include=['int64', 'float64']).columns
final_merged_df[numerical_columns].hist(bins=20, figsize=(15, 10))
plt.show()

# %%
correlation_matrix = final_merged_df.corr()
print(correlation_matrix)
# Out:
#                stars_x    useful     funny      cool  latitude  longitude  \
# stars_x       1.000000 -0.072022 -0.056369  0.068739 -0.028932   0.003799
# useful       -0.072022  1.000000  0.612079  0.767370  0.011554   0.003172
# funny        -0.056369  0.612079  1.000000  0.680392 -0.012496   0.001390
# cool          0.068739  0.767370  0.680392  1.000000 -0.023323  -0.005756
# latitude     -0.028932  0.011554 -0.012496 -0.023323  1.000000   0.429268
# longitude     0.003799  0.003172  0.001390 -0.005756  0.429268   1.000000
# stars_y       0.481501 -0.035059 -0.032086  0.043559 -0.055787   0.009103
# review_count  0.069968 -0.057776 -0.010558 -0.005951 -0.155710  -0.028046
# is_open       0.054466  0.003089 -0.006064  0.003033  0.032607   0.032475
#
#                stars_y  review_count   is_open
# stars_x       0.481501      0.069968  0.054466
# useful       -0.035059     -0.057776  0.003089
# funny        -0.032086     -0.010558 -0.006064
# cool          0.043559     -0.005951  0.003033
# latitude     -0.055787     -0.155710  0.032607
# longitude     0.009103     -0.028046  0.032475
# stars_y       1.000000      0.112591  0.104527
# review_count  0.112591      1.000000  0.172441
# is_open       0.104527      0.172441  1.000000

# %%
numerical_columns = final_merged_df.select_dtypes(include=['int64', 'float64']).columns
for column in numerical_columns:
    plt.figure(figsize=(12, 6))
    plt.scatter(final_merged_df[column], final_merged_df['stars_x'])
    plt.title(f'Scatter plot of stars_x against {column}')
    plt.xlabel(column)
    plt.ylabel('stars_x')
    plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
final_merged_df
# Out:
#                      review_id                 user_id  \
# 0       2fA_8TK24PULHnFz4CE_JA  B7d4_zvYzjE1D-E2fSw9LA
# 1       D9Toy0Ve0j77tp2iHVW3HA  92KVnXQL9KH5A_aX-lnEdA
# 2       M7AGmOpm0PzSdSmP8dA_3A  OXmETnil1QAshKPioX8qjg
# 3       gIUerFG2uz_nJo4lpqKgJA  toOnaUdZoYbdGU6MP8Gu9g
# 4       QyvqHQzpNS1Zdiy88BIb3w  YHzVud8gFNn1MLAKsek_Iw
# ...                        ...                     ...
# 967322  dZR89NmQJR3VtCw3Q2MXww  Y0MjA5a67vfzttu7TENETQ
# 967323  BOTpJP2dh8pej0xZ-w9LdQ  StyRL27Qj1Cy-yRBFuLSAQ
# 967324  fb_xKUoJb-A2wWTSmFndfg  pGmbV55YLG54t8r1W4F3xg
# 967325  2K_TCx1zNTbYjUc_B4_wZA  IU21A35P9AOaG8sgeuCTbA
# 967326  kEORLv45xKdNkNTTUdqpUA  0dxR_Q8PCOOWNkfpvI4t3w
#
#                    business_id  stars_x  useful  funny  cool  \
# 0       gGyqnAlpFrka_qzpO7j4lQ      2.0       1      5     2
# 1       NeY1bH6IKJxnn4YAixibsQ      2.0       0      0     0
# 2       qjGS_7iaQDpbVhS6W8qkHQ      5.0       2      0     0
# 3       lkPAmyZDva5Bt4EaqzjS8g      5.0       1      0     0
# 4       dfKF-oAUf3yjnD0WBYDyZQ      5.0       0      0     0
# ...                        ...      ...     ...    ...   ...
# 967322  QGYzYUMsQe6k7__LD91E5w      5.0       1      0     1
# 967323  JHRlwxxKY0JJcU97rJ-Bug      4.0       1      0     1
# 967324  -1B9pP_CrRBJYPICE5WbRA      5.0       1      0     1
# 967325  xTCSNzu7387VHOPO7DkEzA      3.0       0      0     0
# 967326  eLi0bpsDoWQkBhJX1d46tg      5.0       1      0     0
#
#                                                      text  \
# 0       To the other reviewers \nYou are reviewing the...
# 1       Good menu, solid ingredients, but these folks ...
# 2       This place is absolutely amazing. A cute littl...
# 3       In love with my haircut! Very reasonable price...
# 4       We tried these at the Collingswood Art Festiva...
# ...                                                   ...
# 967322  Really good bahn mi sandwiches in Chinatown!\n...
# 967323  A good place for some quiet happy hour drinks....
# 967324  Spice 28 is a great happy hour option in the h...
# 967325  Yes I am a fan...There are many overwhelming p...
# 967326  I'm writing this review because I think Fergie...
#
#                        date                                            name  \
# 0       2009-05-19 19:12:28                              Citizens Bank Park
# 1       2014-04-19 19:45:40                                            Cosi
# 2       2016-01-17 06:11:00                         The Sweet Life Bakeshop
# 3       2018-03-15 21:20:03                              Kevin's Hair Salon
# 4       2013-08-18 17:41:05                            The Cow and The Curd
# ...                     ...                                             ...
# 967322  2022-01-17 14:36:56                          QT Vietnamese Sandwich
# 967323  2019-12-31 23:01:45  Cuba Libre Restaurant & Rum Bar - Philadelphia
# 967324  2021-11-08 15:15:45                                        Spice 28
# 967325  2013-12-30 11:21:29          The Notary Hotel, Autograph Collection
# 967326  2019-05-02 15:23:50                                    Fergie's Pub
#
#         ... state postal_code   latitude  longitude  stars_y  review_count  \
# 0       ...    PA       19176  39.905993 -75.166640      4.5           515
# 1       ...    PA       19104  39.953671 -75.194957      2.5           115
# 2       ...    PA       19147  39.942203 -75.155223      5.0           316
# 3       ...    PA       19147  39.934859 -75.153675      3.0            15
# 4       ...    PA       19149  40.048754 -75.062078      4.0           117
# ...     ...   ...         ...        ...        ...      ...           ...
# 967322  ...    PA       19107  39.953229 -75.156582      4.5           538
# 967323  ...    PA       19106  39.949589 -75.143910      3.5          1195
# 967324  ...    PA       19107  39.950352 -75.161583      4.0           822
# 967325  ...    PA       19107  39.953083 -75.162187      3.5           286
# 967326  ...    PA       19107  39.949596 -75.161128      3.5           286
#
#         is_open                                         attributes  \
# 0             1  {'GoodForKids': 'True', 'DogsAllowed': 'False'...
# 1             0  {'RestaurantsGoodForGroups': 'True', 'Business...
# 2             1  {'BusinessAcceptsBitcoin': 'False', 'NoiseLeve...
# 3             1  {'ByAppointmentOnly': 'False', 'RestaurantsPri...
# 4             1  {'BusinessParking': '{'garage': False, 'street...
# ...         ...                                                ...
# 967322        1  {'RestaurantsPriceRange2': '1', 'BikeParking':...
# 967323        1  {'Corkage': 'False', 'RestaurantsTakeOut': 'Tr...
# 967324        1  {'RestaurantsGoodForGroups': 'True', 'WiFi': '...
# 967325        1  {'BusinessAcceptsCreditCards': 'True', 'DogsAl...
# 967326        1  {'RestaurantsDelivery': 'False', 'GoodForKids'...
#
#                                                categories  \
# 0       Active Life, Baseball Fields, Stadiums & Arena...
# 1             Coffee & Tea, Restaurants, Sandwiches, Food
# 2                      Food, Cupcakes, Desserts, Bakeries
# 3       Beauty & Spas, Nail Salons, Hair Salons, Hair ...
# 4                                       Food, Food Trucks
# ...                                                   ...
# 967322  Vietnamese, Restaurants, Sandwiches, Specialty...
# 967323  Nightlife, Cuban, Breakfast & Brunch, Latin Am...
# 967324  Asian Fusion, Restaurants, American (New), Tha...
# 967325  Caterers, Hotels & Travel, Event Planning & Se...
# 967326  Event Planning & Services, Bars, Pubs, Nightli...
#
#                                                     hours
# 0                                                    None
# 1       {'Monday': '0:0-0:0', 'Tuesday': '7:0-22:0', '...
# 2       {'Monday': '0:0-0:0', 'Tuesday': '11:0-18:30',...
# 3       {'Monday': '0:0-0:0', 'Tuesday': '10:30-19:30'...
# 4                                                    None
# ...                                                   ...
# 967322  {'Monday': '0:0-0:0', 'Tuesday': '9:0-19:0', '...
# 967323  {'Monday': '0:0-0:0', 'Tuesday': '16:0-22:0', ...
# 967324  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:30...
# 967325  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 967326  {'Monday': '12:0-2:0', 'Tuesday': '12:0-2:0', ...
#
# [967327 rows x 22 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming final_merged_df is your DataFrame
selected_columns = ['stars_x', 'useful', 'funny', 'cool', 'review_count']

# Set a custom color palette
custom_palette = sns.color_palette("viridis", as_cmap=True)

# Customize style and context
sns.set(style="whitegrid")
sns.set_context("notebook", rc={"axes.labelsize": 14, "axes.titlesize": 16})

# Create the pairplot
pair_plot = sns.pairplot(final_merged_df[selected_columns], palette=custom_palette)

# Customize additional elements if needed
pair_plot.fig.suptitle("Pairplot of Selected Columns", y=1.02)  # Adjust title position

# Show the plot
plt.show()

# %%
final_merged_df.columns
# Out:
# Index(['review_id', 'user_id', 'business_id', 'stars_x', 'useful', 'funny',
#        'cool', 'text', 'date', 'name', 'address', 'city', 'state',
#        'postal_code', 'latitude', 'longitude', 'stars_y', 'review_count',
#        'is_open', 'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
restaurants_data = final_merged_df

# Find the 10 most popular restaurants by review counts
top_popular_restaurants = restaurants_data.groupby('business_id').agg({'name': 'first','review_count': 'sum'}).nlargest(10, 'review_count')

# Find the 10 highest-rated restaurants by average sum of 'stars_x'
top_rated_restaurants = restaurants_data.groupby('business_id').agg({'name': 'first', 'stars_x': 'mean', 'review_count': 'sum'}).nlargest(10, 'stars_x')

# Display the results
print("Top 10 Most Popular Restaurants by Review Counts:")
print(top_popular_restaurants[['name', 'review_count']])
# Out:
# Top 10 Most Popular Restaurants by Review Counts:
#                                            name  review_count
# business_id
# ytynqOUb3hjKeJfRj5Tshw  Reading Terminal Market      33044496
# PP3BBaVxZLcJU54uP_wL6Q     Pat's King of Steaks      18245250
# IkY2ticzHEn4QFn8hQLSWg            Geno's Steaks      11658628
# 9PZxjhTIU7OgPIzuGi89Ew                   El Vez      10402368
# ctHjyadbDQAtUFfkcAFEHw                    Zahav       9725245
# 6ajnOk0GcY9xbb5Ocaw8Gw                 Barbuzzo       8603782
# j-qtdD55OLfSqfsWuQTDJg                     Parc       7962724
# sTPueJEwcRDj7ZJmG7okYA           Jim's South St       7575984
# AGlh4ZDv6jnoiYfz7At9mw           Dim Sum Garden       7422816
# 0RuvlgTnKFbX3IK0ZOOocA          Green Eggs Café       7321707

# %%
print("\nTop 10 Highest-Rated Restaurants by Average Sum of Stars:")
print(top_rated_restaurants[['name', 'stars_x']])
# Out:
# Top 10 Highest-Rated Restaurants by Average Sum of Stars:
#                                                         name  stars_x
# business_id
# -FrAoc8_01YaTiwc1zByOA                         Bright Common      5.0
# -LoYGjfeHbGklgmiJU9EMQ                  The Other Wedding DJ      5.0
# -VOl3gWKvEsjk5-Kht1xWg    Philadelphia Community Acupuncture      5.0
# -gWSPVXmvDBbOA0f-hIaeA                      Rose 4 U Florist      5.0
# -mc0GB26tKLQhxKpuR3xUw                          Cafe Couleur      5.0
# -ooQlxiWp21ubVBlLSzM2w                   Philly Self Defense      5.0
# -pPtjsbwgoJjOaI5g5NFNg  Young Children's Center For the Arts      5.0
# -puKoJtGHpbPv87jZTR0zQ               NovaCare Rehabilitation      5.0
# -rme923YftBvVWv9omz8Ng           The Boudoir By Cheyenne Gil      5.0
# -xxFeiRIn6XGs9n8YnR2BQ                          Matin Tailor      5.0

# %%
# Find the 10 most popular restaurants by review counts
top_popular_restaurants = restaurants_data.groupby('name').agg({'name': 'first','review_count': 'sum'}).nlargest(10, 'review_count')

# Find the 10 highest-rated restaurants by average sum of 'stars_x'
top_rated_restaurants = restaurants_data.groupby('name').agg({'name': 'first', 'stars_x': 'mean', 'review_count': 'sum'}).nlargest(10, 'stars_x')

# Display the results
print("Top 10 Most Popular Restaurants by Review Counts:")
print(top_popular_restaurants[['name', 'review_count']])
# Out:
# Top 10 Most Popular Restaurants by Review Counts:
#                                             name  review_count
# name
# Reading Terminal Market  Reading Terminal Market      33044496
# Pat's King of Steaks        Pat's King of Steaks      18245250
# Geno's Steaks                      Geno's Steaks      11658653
# El Vez                                    El Vez      10402368
# Zahav                                      Zahav       9725245
# Barbuzzo                                Barbuzzo       8603782
# Green Eggs Café                  Green Eggs Café       8079987
# Parc                                        Parc       7962724
# Jim's South St                    Jim's South St       7575984
# Dim Sum Garden                    Dim Sum Garden       7569846

# %%
print("\nTop 10 Highest-Rated Restaurants by Average Sum of Stars:")
print(top_rated_restaurants[['name', 'stars_x']])
# Out:
# Top 10 Highest-Rated Restaurants by Average Sum of Stars:
#                                                                       name  \
# name
# $155 Flat Rate Hauling Trash Removal  $155 Flat Rate Hauling Trash Removal
# 13th Street Cocktails                                13th Street Cocktails
# 215 Pet Care                                                  215 Pet Care
# 3 Girls Towing                                              3 Girls Towing
# 60OUT Escape Rooms                                      60OUT Escape Rooms
# 8 Limbs Academy                                            8 Limbs Academy
# A & M Auto Body                                            A & M Auto Body
# A Class Act Auto Repair                            A Class Act Auto Repair
# A One Auto Sales & Repair                        A One Auto Sales & Repair
# A to Z Exotic Hardwoods                            A to Z Exotic Hardwoods
#
#                                       stars_x
# name
# $155 Flat Rate Hauling Trash Removal      5.0
# 13th Street Cocktails                     5.0
# 215 Pet Care                              5.0
# 3 Girls Towing                            5.0
# 60OUT Escape Rooms                        5.0
# 8 Limbs Academy                           5.0
# A & M Auto Body                           5.0
# A Class Act Auto Repair                   5.0
# A One Auto Sales & Repair                 5.0
# A to Z Exotic Hardwoods                   5.0
