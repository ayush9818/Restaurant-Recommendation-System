# %%
# Package imports
#basics
import numpy as np
import pandas as pd
import string
import re

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

#viz
import matplotlib.pyplot as plt
import seaborn as sns 
import matplotlib.gridspec as gridspec 
import matplotlib.gridspec as gridspec 

import json
from tqdm import tqdm

import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package stopwords to /Users/yumin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Read data

# %%
#business = pd.read_json('/Users/yumin/Desktop/Winter2024/421/Project/Data/yelp_academic_dataset_business.json', lines=True)

# %%
# Read business data
business_file = open("/Users/yumin/Desktop/Winter2024/421/Project/Data/yelp_academic_dataset_business.json")
business = []
for line in business_file:
    business.append(json.loads(line))
business = pd.DataFrame(business)
business_file.close()

# %%
## Find top 10 cities with ratings
city_counts = business['city'].value_counts()

# Show only the top 10 cities
top_n = 10  # Adjust to show top 10 cities
top_cities = city_counts.head(top_n)

# Plot the distribution of the top 10 cities
plt.figure(figsize=(10, 8))  # Adjust the size as needed
sns.barplot(x=top_cities, y=top_cities.index)  # This creates a horizontal bar plot

# Adding titles and labels for clarity
plt.title('Top 10 Cities in Dataset')
plt.xlabel('Number of Occurrences')
plt.ylabel('City')

# Show the plot
plt.show()

# %% [markdown]
# Phily has the most ratings.

# %%
# Extract business_id in Phily
json_file_path = '/Users/yumin/Desktop/Winter2024/421/Project/Data/yelp_academic_dataset_business.json'

business_id_list = []
#city_list = []
# Open the file in read mode
with open(json_file_path, 'r') as file:
    # Iterate over each line in the file
    for line in tqdm(file):
        # Parse the JSON data from each line
        data = json.loads(line)
        
        # Now, you can work with `data` which is a Python dictionary or list
        city = data['city'].strip().lower()
        if city == 'philadelphia':
            business_id_list.append(data['business_id'])
        
business_id_list
# Out:
# 150346it [00:00, 238310.08it/s]
# ['MTSW4McQd7CbVtyjqoe9mw',
#  'MUTTqe8uqyMdBl186RmNeA',
#  'ROeacJQwBeh05Rqg7F6TCg',
#  'QdN72BWoyFypdGJhhI5r7g',
#  'Mjboz24M9NlBeiOJKLEd_Q',
#  'aPNXGTDkf-4bjhyMBQxqpQ',
#  '-4dYswJy7SPcbcERvitmIg',
#  'ppFCk9aQkM338Rgwpl2F5A',
#  'eMjnw_7wp-CscyNh6Lu0ZA',
#  'xfmkEGiIERBaBMLhw-dTCg',
#  'iPSPcprSnkLOuL1Ns8UZZA',
#  '3BJxm-HnvzdwD1zjmSbmyQ',
#  'GWGXTKR0Fhdvzf_isDqJug',
#  '-aeZuatjCDMV1X4gCTz9Ug',
#  'h-y5azB-VlQAT3m7Ff2g2Q',
#  'WYYdQDjx-DsCanlP0DpImQ',
#  '07JLsUInZr5OSiYH2XVi4g',
#  'FTFtoylMzkrzqNVSl-bkKw',
#  'O1oZpbZNDMH_gz8DhsZCdA',
#  '2dlQX5sP9X6Dlm1MmNOlSw',
#  'ONUZertKOOImiyQG66Z7Tg',
#  'bTve2mwLk5Zc01vRKqc2KQ',
#  'D9Xez9uOSM4DgSjSTywq7w',
#  'MyE_zdul_JO-dOHOug4GQQ',
#  'bqmX882_6AxVA_uHEQ70sQ',
#  'jL_NufxqXi-BpW5uXKsPwQ',
#  'Tm3QiAVLJAR2fEJK7APPPQ',
#  'n8ecak12IF_jhnPNs37AZA',
#  '_T0cPZE2ZJOTTlYYKMP64Q',
#  'VbItL6RDULtnw4YvB6EhVg',
#  '6bFx8j2KqPfmT0XEUS1RMg',
#  'G2Byuh4EVeSnqqWBWtD7rg',
#  'usv5G5cO314pPHRTGq2Eyw',
#  '6I_DA3uqOox50rBvjrQ_-g',
#  'e8pMCk4bE0U4qk7z59Lxkg',
#  'IAj1Lw3FAOY-yZn4IO7ElQ',
#  'aNLr1j_3CZ46rqiUeLaQ-A',
#  'yZP6Z8sbDpkeXyjNMDiyDg',
#  'kR4tXc1fLeR2QNu8cMZrEg',
#  'V-96iACFgPmVjjKACGxd7Q',
#  '0CEUpFtaKhxbmrbSdP9MUQ',
#  'I0gSLthWBsiUPzBft_CZ9Q',
#  'yooufdsf3eAVq_9RQNSDJA',
#  'GVqXNt0HKJLpciN9ePxnWw',
#  'dChRGpit9fM_kZK5pafNyA',
#  'cDekcTE1qwpz8ROlYixhqg',
#  'gVh26yEPkXSoWbhs1p2kNA',
#  'QWqKTWQ2OiDgo3dzNkpung',
#  'eJ77e9lGxY3ArzaoDbHhYw',
#  '2M4pYfuivdluXyBOP7IDQw',
#  'i_cFU5_dQexbjJA9rmf_WA',
#  'tUl_Lq8dM3T-NnM-u3szSg',
#  '7mpYTDb24SywNMRn3yeakQ',
#  'dK_qONtd5z73i6fQ1BTrTA',
#  'xDEee0p41GueCDN0EAp-YA',
#  'oy-n3wkXeK6NPPKf3uRDTQ',
#  '0WIlsDUUFuUKcDfJPaHRkA',
#  '5iuo1kvv0XZMS0bUOoLz2Q',
#  'bchZXVE4feVx4Q5rhIRCGg',
#  'yUEeh9nwaycI6fKLruD_rQ',
#  'ngvE1G9IckUO-ljZBFo23w',
#  '46_2e1hnQ4csLrYnhn6bkw',
#  'TGfPJHImEq6AQL9a1laxlg',
#  'CPgWuWGZ4v2sZr5_-1kluw',
#  'gu2-TPPdyQyHl2CnPb7Xjg',
#  'VCkSUsdL5P0p16DAPxVROA',
#  'Oy7rU9H76PN1hsDU9EUt5g',
#  'PW5eZM5RAQEhy3wgovChhQ',
#  'xY0jpu0zzGEBr-bGBdPs-w',
#  'yFqq66GxRjnhZXPgjA6hnw',
#  'rh3C_JK4NAoUJ-HNStvHtw',
#  'xHspDrdyq1g27yRDezB5yA',
#  'wR8V8u3_wv-yjR-CIHyY0Q',
#  'kGjpBqAqG4mIuFSgU2KKEA',
#  'kLSEk3qXY1KdtFjxHJ9pww',
#  'kfGz2E7Y5FLXJyiKbQYfZg',
#  '5bCsL-Z3QnuBmJQtIt8qyw',
#  'PdMXmOWDRHICAx6SLgu1dQ',
#  'uzpiSVy6DTQBNByAhT0Z2Q',
#  '4mKAD2m2ek-z51ZPqL6-aw',
#  'HQolH8hSvmK8mhZc0bYVRw',
#  'v2UmYZ1rPT48IroaD0xZAQ',
#  'z7sp6u5JnNlq2ziu31EFvw',
#  'JomDoQafikclSVVCPkWjnA',
#  'F6hASqb_Z5ASXz0-pZFlfA',
#  'LvFmVnPSbi0lmgpcK_qw-Q',
#  'kq5Ghhh14r-eCxlVmlyd8w',
#  'MYoRNLb5chwjQe3c_k37Gg',
#  'pP4q0Mym-qt20nRqTKbzhQ',
#  'zyge4T5eSiPHq1-IaJb_Qg',
#  'PkaxfjwdWKL02xkK2UGxNw',
#  'TF4IyHKK05m5rXENCK94nA',
#  '73vXXe4MbpHhq_2_uiHIrQ',
#  'Htnv87XCc9GXuE6hKEHnNg',
#  'y1HgVnt4K5owmYXC5yXLGg',
#  'x7R0FReViemWjQO581WI5A',
#  'RrqRin8BYGrTlJbCDwtLzA',
#  'IgNDlyLERBwFGphgcC5VDQ',
#  'Tr1K019SoddjZegRv7vy2w',
#  'SvcWlFeXbSNkENnZfWYgEQ',
#  '0QmgzzPVNHeNL76B8rwTKA',
#  'sDOxVq8gQBpHFYtoxwoLWw',
#  'PmASdGXX3XVokN2q92JIXg',
#  'EraDGJAHjf5IaA9VBGepfg',
#  'L_sXNadtVHjxMw7Yhvkj9Q',
#  'IOroNIZhOtGM9nWMT3PaNA',
#  'HuDNHqKv9n1mWpe4BqCnwA',
#  'fN1xl3d8EdFRpyE1NVI2nw',
#  'lKlRRS26_eTA_eCjrWBT4w',
#  'BxR5hjyBnJZrm_nnaCtGQw',
#  '4TQMOy00KD_54xSFwKgMZw',
#  '-BhSR6dAry5-2x3ndjX_9w',
#  'cIKRTajdQv_MviWXdE_m4g',
#  'NQSnr4RPUScss607oxOaqw',
#  '6Bos3UU5heFlqySLcYvwnw',
#  'V6Om7YZhlRQRU7WfuxHq8Q',
#  'DOl21AqtT74dUZ3kvXNNcA',
#  'I4TFiNX5gTsJBnEGH2Tl8Q',
#  '12kD46cnLyMXUQTCI2N0ug',
#  '0346ZLBXCnsGief7r2kmQQ',
#  'PvT44WlqJLkUrCITo6AjRA',
#  'FppJo5aymUsfOg68uTOipw',
#  'RMm5FeJpYGZlGJIVsqz0Yw',
#  'tFh0DrDMTom4B3pHpDpRNQ',
#  '-IRJAg0tkspFukxKY87TBA',
#  'N1ZXhAVzOzbyCBPEXTaUUw',
#  'e7PUSXlcOfel8c7sPIA28w',
#  'nBr6NgqcZz1GhtAngU0RSQ',
#  'afmMy0m-mH9uNUxaZZAKpQ',
#  'y44MbCvvtmg1FpkNGSWisw',
#  'xb-qtXVZ7xFr51Se5fAZjg',
#  'FeEYBozUzyVGisE3HPGbBg',
#  'LSdg7x7HhUdvYUevvYVHjQ',
#  'hlqnFy34n8tnVNMq-pO34g',
#  'n30JyruJKfbIeSReuYQloQ',
#  'icbe_DxKtXG2p3KlJsqYig',
#  'irH-OtXTEkR6Ovjs0YD8DA',
#  'U30ggGzFpXvc2NZYwOW3qg',
#  '2N_54QEPZiqT_A-kgCLzSQ',
#  'iefY4RDGOZrATgYaXqbx8w',
#  'mVEu88jgK1Y6A5fmJbydkw',
#  'X46tKBT7vTEGeaYj6GkZ-g',
#  '1PIu-evesG5ZQQoHtXUXiQ',
#  'WZEhrN61ajiq-7MuUCGyuw',
#  'he6ypFmnUF95PlNUWT6i5g',
#  'dE_MaaYrXBAEebtH2u_B-w',
#  'w3R4cgg_HPI0F55PCLpufA',
#  '68ThEdiK0eWCEgGEmV9Tng',
#  'vDqnQGBfPUOUichR2KbDTg',
#  '8fTaOcdyJwJJtN7dbRNpiw',
#  'zQKzntycRKXbDHSjrwkYkw',
#  'USyJiGIvZ8fHjRVaVTu1Zw',
#  'u8ZsK3py4y9xEOk-vox2ZA',
#  'cEG1r9aRMJwmRQVkh7eiJg',
#  'ZrkdPWQicriMCcDVDX0dCA',
#  'TttFjRQ-8Iz8by4hsD7iOQ',
#  'evZKyAZ4UePe8RLPzBDcbg',
#  'NQn_dGaMlvbQGwgAA6t85w',
#  'pCmaISSyKum22MOtPOxL-w',
#  'aurl4I40YVQfQ8loOdgKCg',
#  'ctDyeSkk2VMEbRogxAtYFw',
#  'tThP9jkCZHTrFvwEhGeKzw',
#  'di5ihAL9VWoctHelY8kLTQ',
#  'Pb5agnsD9EdCl6yuZp2jJA',
#  'qluIWCzDpeZfddykm_2gYg',
#  'Bw0cpnfI-Y9QmjWzqS-oFg',
#  'wh9WMoi0ukhQy-kvjpC4uQ',
#  '1w1H1kYUN60zpfdP-0qmGQ',
#  '3VKE0_-KhU_qMYHxcyVcDg',
#  'rApVTXXz2sUrNfDAMAIeNQ',
#  'Mw4seO5ZXpAIHxVnWzkoOw',
#  'kgMEBZG6rjkGeFzPaIM4MQ',
#  '2xILZFIFZsPIxNkKH8aJ6g',
#  '2OB9O5u6yrBXw4V03si_OA',
#  'fKDV_dlDhXd7P5kZi97Kng',
#  'XgLrkmIqIrD_pl67lAovEQ',
#  'usFEKg4-2C48qPIh32HbHA',
#  '_IYHl6J9iB3lbeJq27pbsg',
#  'ZyyExneJPXjci7yc2CGAPQ',
#  'Ryt1Fhgz7sixMQSJiLyP_g',
#  'B6qHZCAs7Nka-1zdjCzAIQ',
#  'Bb3F76xkJrA-IwXLNK52RQ',
#  'y7qvy9LcyK2hr_VcPBiPaQ',
#  'F6lNQPwg4gyg76wNyimxjQ',
#  'AAFofLiyt_K1Ar_eEuVc7g',
#  'XZN4nllA4qMdXVHy_-nqHg',
#  '-fqjV6QqrKLUxpYCJoSsOQ',
#  'DVhjFN8N-jpw_EC_-Uoxjg',
#  '3Lf3nWp9TcIj7hvw9YZeMA',
#  'NouhbGP5s17DZ9hExLYAkA',
#  'KAZ2Z3831eb5lHtUDKa8kA',
#  'cLlBDZxYJ1dt1JgMuZnXew',
#  'V5KiEoH4E86GA2S3RQkf1g',
#  'MMRRS6YhVRx_iN5-JhMRYg',
#  '2Eb8aKOZROAPkWxsBXf_qQ',
#  'icp_IKE9zIkAqAucyS1vTA',
#  'h5-Ay4V4XbRu-MvWyYC5yQ',
#  '2oav5QoWgnvTI2gO5xFMjw',
#  'f8xDi3rajxvIqS73N93Afw',
#  'A0F-h3xJm_6gHDKcDQwSrQ',
#  'PGCTib7KxDctvNnQry_iDA',
#  'SPWyzJPFP2TT7x0BsqaBqQ',
#  'Knt2mnsG15akKb9cjSiuxw',
#  'W_ZwRjARpALtXUlSW90tIg',
#  'twrAccrzOnaRtS_UaZhwTw',
#  'ugSVRAKO6mxvsrElFg8USw',
#  'Bc3zpRSQ_1i18SDI1eb9cA',
#  'E9NdANM1gVijPPkl1K2CDg',
#  'mpVZG520RL-K1YeQi55ZPg',
#  '9VRg8Ho9SoZWKPmjfrpVmw',
#  'duf2PORLOL6it1dTGhSnKA',
#  'Ye0slMJ56gXMZChM9mU6QA',
#  'klGvxx2XmKkd-9mdRZoGVA',
#  '_7txbYafymgB-xqbsdWJjA',
#  'LsGhInbkQ8jUNn-defi_fg',
#  'bKppmYKQ_-9cpp2yziB-Qw',
#  'K8b2MQ5Az59-nzvqUfjJEQ',
#  'We57TJLl3BEo2gII0TWVQA',
#  '00Vn4VUTWl71_cFPziRQNQ',
#  's55Hw6gHhQzZctinFhPu-g',
#  'n6dw_zxL_4cVO6EP_m0joQ',
#  'agTcS5LYZJe4gNiXK6nNkw',
#  '6SGw7TF7F4q4Uc2cuGvwIA',
#  'Zk_GdMMPgEfKUECCxAxvwQ',
#  '6vdj6TAQv82kXE6MEUg7tA',
#  'PxEiXqMAzzvp8GFlb5EoLg',
#  'ErWSqXjjX55CvAsTiVL4yw',
#  'AWGuQflJGycjeHfOZjAVUQ',
#  's_NhHDVXGyZ1mjTu4D9fXA',
#  'ZT8ZBNvjV6OVheYOZcT10w',
#  'kfcz8iJOkltAvkp6TqNMcA',
#  '9xPFNAQ5vG7PG0VD2rdoIA',
#  'w0zKpH49tW6Y-b6ZJzKMFw',
#  'rQ2CSHRkZSn5WCu7OfVI-Q',
#  'eqNutOMnPqKa9QDAY6KfEw',
#  'WiF0TF-648bQsZ0dYyhpXw',
#  'BmRiZG7YUTQ1lfK61J6zLA',
#  'sfbg2kxnvKpmlIuCUas5TA',
#  'gpOUCroDdMBXM_Hav3FFXA',
#  'DrVl5UFuhbud0DGTzCiUDg',
#  '5YGfTrvNftNIS7qAF9qikA',
#  '8cLbpSZOHnmzxzDNSBGQCA',
#  'S5zpryZNidOZUFcfznfhaQ',
#  'CB7nXPd5h_YLzcgfDo2DCg',
#  'C2KhibuDzv3HJvZubkHTJA',
#  'i5DH8fyS7JTu61qrIgRRWA',
#  'ttLa_rs6CZOcBZN_XWEAwQ',
#  '7lwe7n-Yc-V9E_HfLAeylg',
#  '0kLivwqFCIAb2V7Vhndpow',
#  'o4_cgIKWgvJ09TZeSzARmg',
#  '5m3ND7lNNd6zo-bNQGoXhQ',
#  'IDGg4Ax0iMYBtSKRP0tBbg',
#  '7J81xJFlMM244_f05k2egw',
#  'Sv1VsMRwedFaRgodPlmBVA',
#  'oBhJuukGRqPVvYBfTkhuZA',
#  'e0aGg7U132XQRup2qa0Ztg',
#  '04UD14gamNjLY0IDYVhHJg',
#  '7sKfrJmjG6unAQeWdQUe2w',
#  'pXb7pDVPayyElIqVlh1FOg',
#  'swiwJRUQHt79dJ5hqAERtQ',
#  'Xas13kiNejlJtRdejpZ22g',
#  '14ZGwnDyydXdSBsLXpSUrA',
#  'FKlNp7sCdEIt8_tQ5AzXDg',
#  'dKfMKFaiHC_9XLHdqhFN2w',
#  '4NjPz9bJzll1FMIi2bw8HA',
#  'i221dg3tgAMZLG-zeS5k3g',
#  'syB4xhM0hiaib19fucneBA',
#  'XDvsDfLRddgpayKv7Mcn-g',
#  '96752mk7VlAUtWg8o02Tvw',
#  'tzVLTQNUtiCAxUZmEuF0vQ',
#  'AY1SyySRyTnBwBdf7qfGxQ',
#  'kCK5pdQCh56eCnWpLcNt9g',
#  '9XpU6r6ATXSWYfbU7kibaQ',
#  'sD2yBIzp0SNYRMD4QfH9Jw',
#  'cz0sBSp8G2R2dqE6cccbuw',
#  'Lro-qULT-oa4Oz36p1yTwA',
#  'FzrbnV-9y0LkksceBa863g',
#  'x5RQogP-uQrhW0cFRkZuPQ',
#  '1k3SQfqkQHzaDihUBG2_og',
#  'LiisV3YRS4CrVbMeEbn-sQ',
#  '2X6HUYGV7Djr_TFX6uYebA',
#  'Yl4Am6NhqWo_YMmo1SyU5A',
#  'ld1b8y_PHH6Mn_e7T0u04g',
#  'aZNiVR6oAMQX5__yGPvYsg',
#  'MJisxR8XOSfDDFqU8PtiCg',
#  '55GNarL5MuVzJEslW7QjbA',
#  'WxFfnTx_VAT_ORvqHAfYNw',
#  '2oNlM0ANjE8JB0jEwY-mtw',
#  'ejRuEF2j8_w5qQbwEQ8GfQ',
#  'zVmW-ohNzhOPiBIeUPL62g',
#  'pAVplVUnmW9vMUJbiDVyjw',
#  'MGNAYydr7SxPMDgFlnZ7sg',
#  'R-HCwu9UbasUudG1yTM1Ow',
#  'oFMpfE5J6f0ATRmsVXrFSg',
#  '6aZGNR-R1lSBlG9rPsyEyQ',
#  'tCLAeZsjXFG9RumJ4Hn0Kw',
#  'frOmFhJME0yZ3HkyQov6Pg',
#  'ekqJffSZGsAN9_v-F2yrSg',
#  'rm2XUoqkJn-d5gByPUwamw',
#  's1PNBO9o5jIgNd5YWUDLXQ',
#  'XdmaLMJE44rg75TYlOACVw',
#  '7gKh-cM6TvfpQPMjMoEbGg',
#  'HUikwo_T9mnpgk0M7oUHXg',
#  'ShYwqkUf7PkI7LHqCyTmEA',
#  '8Uz6dy3vMQsZTQu-vqpZ5A',
#  'T8lxi3V2avTVXCanVkAFNg',
#  'fYtJnehmqvxXFmRsPsny_Q',
#  'fr2qDm_mY1afIGMvqsKUCg',
#  'X2D42cGnqxadT_jbNJxHsg',
#  'GOSVLhjUT6TnrPhkkmDOpw',
#  'kOHcpCZQd4uNp6G2uE8o2A',
#  'ELJcgId3RiCADVIT5QbUTA',
#  'h85b3MFPWyaopMBy8DpBpA',
#  'w9hS5x1F52Id-G1KTrAOZg',
#  '9TPek1DI_El4uu8ltDzfcw',
#  '_tADqh3OmH6CzGJWKkru3g',
#  '5Eq-hxUIIjZTHFnpZJhgQQ',
#  'c8rjE6NcfeyzLB_aU1GdMA',
#  'T3m-GF4HH7OCdZW3tUxxLA',
#  'GnwEsZCA8gzKDB-pTRl3nw',
#  'mCo2uVTTGYrEhRrkQW-CMw',
#  'Oom9PRZP9L57vHKQOA3q4g',
#  '-LmhsdQproqCf5EQoD06rQ',
#  'ydIiHK4TE_wd7gAyifNUAQ',
#  'afsP-p_pr4ikrboB5MtUzQ',
#  '7MaaaorooHRAqkQXcTqmrg',
#  'JXXLweAoAOBP6UtmFQe1lQ',
#  '9nkYaCQRyO0fi8SrXDFhGw',
#  'QIuU35su_uePIkn9o5a57g',
#  'tVxL-Ygzwp8NMuxwvNmWRA',
#  '9Y0jUKfeDFJUStlVHOlc9Q',
#  'NnW7PyUW44d4nnC9XY1naQ',
#  'CPpZTp1Lezhsfan8SgJs4Q',
#  'ed-eGpyeu6K7pHWoqnvOkA',
#  'H3yoQNhw-AfdLIwScR1zXg',
#  'arpAjDjebOzjwwysIGIwAg',
#  'rVfe1LHo55A2fworkm_jVw',
#  'O6hY9yenifuRXrpc4TfgsQ',
#  'dRdpyxn506UOywojRIKLhg',
#  '-V0vIgo6196MDn_x3ZaYmA',
#  '1hQobBzUoF-H26URYtT2WA',
#  'ZMJz4ekxrcZdhBcnK4B_6g',
#  'UaovDcnP0QzsmGf6vXvg9w',
#  'x2J-YIFeGZ-nsezzooVA9g',
#  '7iv9l8x7nr_s536GiFBDXQ',
#  'kLS3Sth5HvO0IjrXCCvXxA',
#  'sdWuLh-auc0nC2Jy6_26AQ',
#  'jFmS7S0kU5ZQHSm4jqymQw',
#  'qKtkYb9lyQj_psgyg_wQlA',
#  'AHAPYD1ADG6MD8RB1LprWA',
#  'DjXYVftTF62DVdTMGdCa-g',
#  'eDMFTNR_o3Z2wK8WmAo77Q',
#  'fnv0PrzcWoopJKuVMpCcdA',
#  'AtYDSsVOZT8DLWCcTBqZmQ',
#  '26Zx69vOllucV5OsHXst9A',
#  '3CsBRtDT5WOUu8IY0mHhXw',
#  'nP4LqTcK1USiw5WnbOjW7A',
#  'hLkNIMWIy2_16u5PbO8moA',
#  '5yFIS8But4LUm_XT5Lk-Xg',
#  'REns5fQe45Nk_D2UwQyr0w',
#  '1NCUTTp6rIyXpwUDVv9qOA',
#  'ry5vJHVytH0LvqgheGj-8Q',
#  'Mgf-jjzsZh7-pjX-q-zTLQ',
#  'HHWTWs8sa7cE3ksH3_BCTw',
#  'EneM1oBFxncaR1nQCD3gYA',
#  'vLpLGCbAtuxFzu2ka138aA',
#  'qHCfhWPyb1GXpzq9Wk3Vkg',
#  'OP-m-Kq-1aEWrrlaszFi9w',
#  'o6jpcwA4mjUXZrVdLmOVvA',
#  'TcxygVM59WZrP11nlIMIOg',
#  'lT-RDsvFR21X1_5UhFp5Dg',
#  'rg6z4zFMxjj16qAnJ65gxg',
#  'j1TPHqEtXGSqVuVNNX8g3Q',
#  'mDgePM_zCK1dyTmozZM56w',
#  'mUIBtlWNPD7sz3rGGWQ1RA',
#  'SCZcGXrZgWzubJiQuKn2JQ',
#  'D9lnOVIpb-0F9DfcQN_rgw',
#  'G_Qhti4qDgecDduv2rKS6g',
#  'hxEo_CKsmSMGXcHNLR9oow',
#  '-QwHN9KoluPcA0YFllwFYQ',
#  'Y9q3d7sF2k4FOxSBBHdJKQ',
#  'FSR2ErBcsgsRpAWtU-xxYg',
#  'RkI3Poei2kGVyhy21N0quA',
#  '_FlhRk9KjdXyE0sLxUdEBQ',
#  'i4iZdyneMKGEc729ogQhcw',
#  'dSPA4yql9vUwnYRxHiVtHA',
#  'Utc1KFuFQ-wwLiUTj5FvmA',
#  'z8W9DGBbJmg4aPfEYLHhUQ',
#  '5dj-rJ_0gNqdhYL_MbXuXg',
#  'Tdz-vjDRKI6LRzyaW3BMkg',
#  'hPeUz0HqT82fOhJ0ayyQUQ',
#  'gq4zw-ru_rkZ2UBIanaZFQ',
#  '-sRtgVuwRz7JJQaHiLV9zw',
#  'h0Gy4HEgeZvN9kb3_rB5JA',
#  'BWITd9JUXP3gSi1z3Y-z8g',
#  '-mY6tC7PXYOL40vc_SYX4g',
#  'OTBWyXkNsBYHqIlXJXnEDA',
#  'm4lkv5ksqtdXvlIVIftH_A',
#  'iIpF-IdrX6y7gPI_WDVXQA',
#  '4EDFnzdMBdrL4tujAA2QZQ',
#  '8LonS_bxNmCDk3FWiG9lzA',
#  'byYUYIXVxS6IUXC42THYFw',
#  'cqIYskWPVQ0rz1XSG0ohxg',
#  'jTI5Xjk27An8ceJ6VwpXiQ',
#  'Ydo8zFl1PaO--g5zwyVyVg',
#  'IZ_syZp77K1ewunXZlVEcA',
#  'xruWHK8Z5N0JWyQubLHjgA',
#  'Z-jOXWIaHaP1KG0cLXTkLA',
#  '9AYJIH69QmqyZ3qvNhvEaw',
#  'TFnGJlA5l_HDdzGDkNTdTA',
#  'hwXDlBJdtr1cFFM8sy5oPQ',
#  'dO4iyNK2KzLMe1kXLCskbw',
#  'sRDiX4oYa2VIHMWJx7cDzg',
#  '2er_V-oAd7IbQ5YTY56r7A',
#  'FmQygwfW_x8AkEWLXESezQ',
#  'NjUjzEvHfyRcKI7VYwLY0Q',
#  'M0_Yc94Yq-G7HV8rrl9fQA',
#  '4i4AA184MUz3wobkhdAA3A',
#  'C7ZNfxgDQWinNzRfTkevxg',
#  'I5KZm-NnxYeEQsmp6nK5_w',
#  'Bb4mYZA4qda-2OP6Gku0SA',
#  'WJN51928dvjYmaFw-zPKXg',
#  'I8eSWVzc_y9ORuKWgl07Tw',
#  'BOUtTh0u4TScrrPMBmsyPg',
#  'P8QLcGZZOPgl9w_3ARBKiQ',
#  'PzmxNRjfOQCaKgSI8O_MKw',
#  'kTLHh3e_59XZduNwydxuAw',
#  'GIq9z7R9e497A4kv6rGhPQ',
#  '89CEDMXZjJRHXGeVIWTwcA',
#  'WWUJTTEcN_J3AZcS8BbCiQ',
#  '4BCKlTVLcYfBp5xwdC9z3g',
#  'u51xmBHAyiq6BBS2pRt8qA',
#  'd9VqIHwmNj1VOfZc-gWwag',
#  '262I6X8Vi5PXygFmhjeLyA',
#  'Vq77GKtHp2nMsiKbjumgvA',
#  'b3YIPBHXoyZU13-HFBJv8A',
#  'zUJMvjK6aBeQtVCowZ85-w',
#  'vdpxxb6fxjYtJMnW_V0GZg',
#  'VGrXV1lgO8skquXUyeWgig',
#  'XQ_wVhRayMJGQT9J_WANkw',
#  'WZPCfTRiN4ipajP7gFfziA',
#  'gXy0a9tOQYLGflwRtqmY5A',
#  '8hgo446H2HoYlZocEi1SJw',
#  'jhkEcEtWalfkRN7UmoKv5Q',
#  '6OqdrZ5rh54m-MSQK-yqdQ',
#  'eJhXqSKaYzDS4WBeDq8vEQ',
#  'ne4NHcrVU8ZakOOg-lnB7Q',
#  '6D_ZBVcUPje3IyVg1n_Edw',
#  'liy3id4Wj1AaIduwETiVSQ',
#  's_ypQXJm1d94PfmY6JLzRA',
#  'rAUaBd1BMOrY9K6kZzcEEw',
#  '6jNFUIKiCCKnLCpGJpkyrg',
#  'YJ4jzBFJU2EJhM-zatdLRQ',
#  'Hj_mWzPoyyX1es-a_x1eXA',
#  'M2mkUv39B6E_1UOC24gPqw',
#  'egtZ6tRJV-MtSsjQESTM-w',
#  'zwTmOj4B_OVPMTMYijQiKg',
#  'UhIdCsdiWS4K0EkbvVdlAw',
#  'BVe-jR0szZPC6o7r15jp4g',
#  'hBoXl-5Evn7ScoY65u2TwQ',
#  'Bih0eT_lbbCUwKmGYpX0hw',
#  'qot32tHVWZpiJibLTwQGyw',
#  'UaqDNhnmVFhFkVwcp_mBRQ',
#  'u-MF7O0mULjBnjz71fNplQ',
#  'RI33oswGDkIsc0fuQ8GzjA',
#  'Bu-hZZaseWQ6wb15DpkLOA',
#  'ta7CjdjmH9cVcwc8AQyUFg',
#  '-Be75AsLHhBrrDYZwfwSCA',
#  'gBaiZpCFNEx0gIJQrHWT5w',
#  'YWfOxkw6ZqMOsVm3hsv2ig',
#  '1pkuCWlH3iEuUAQVHpIuHQ',
#  'ukt4QdEiwDubi991eF75TA',
#  'rjuWz_AD3WfXJc03AhIO_w',
#  'cCP7ued6F6ScOpQSVs-Mrw',
#  'ZBaetx-wjXvQVzfB_OnASQ',
#  'JUVtr9lqM1dCaiLPFPCeBw',
#  'CTCYk-k84VA5vCkRgv03Dg',
#  'HFuAKE0uZ-frIMjroeA-cA',
#  'aAMop7hpw7rtLL0bnS5lLQ',
#  'u2v1Ml7xb-l5NUmOk5bcNA',
#  'qWTzwt7IyrElM2g9nVHm2Q',
#  'XLEgHW4tdk6VMt9uy10aog',
#  'E-DcL1u330qwvoxXhipmUQ',
#  'GUNpbcLvHZLE3NpOifjNUQ',
#  '8ZcVHh6cFEd1Nhqgqp11Hw',
#  'Cv0yn-dxwg9lJVhu4i66_Q',
#  '9EgoCSRFfXUEGiJWFQLJ1w',
#  'eFvzHawVJofxSnD7TgbZtg',
#  'CIKlh4vEQy6d1lanzmDQXw',
#  'teGUSCn6Vlrs07qIgilFHA',
#  '6RUY3l7pQKk1HhM3uwGQSA',
#  'm1DE-V1QWEkQ_vtwB51rzQ',
#  '5S3Cc7EsEo66BSL7s6iF-w',
#  'KuLi91b-N_0XY_3IA72RJQ',
#  'NOPk3f5TedR-fw9HO4VJlQ',
#  '7jTaLGVD3jy9VF7lxPEgww',
#  'qT37Sz23qPG08y9Q97QVnw',
#  'D6xXxefPLQ70JhDKEQk_3Q',
#  'zYty3y2eQZQfdCSzyUUbzw',
#  'eA_FpMeiRDk7E1Zte_CHgw',
#  'c6r29yLfVhZaSyrtsNVLRQ',
#  'Az1Xl-Wz_VXgswIW4OyAGQ',
#  'H1LPlb5J4K-TmSRruICJug',
#  'mNu6xYO2bn-rvacN12h9WA',
#  'SIoCIxjn4jLt2O-4DajWJw',
#  'KuMz8-0-uEFlaNQrzsD_9g',
#  'KrJyAjAUnZZB0nbVAroSCQ',
#  'Pd-r2emx-k0GB3f2Iv4-zA',
#  'yBLLLb6mD4fI50ew95xP0A',
#  'E_WLgiNMLk1dH7QYd_grmg',
#  '3kiB39JzdovdlOhQj-nMCw',
#  '83IeQHroXEctmMpK19TJKw',
#  'm3KWIfQQFGcWdX1fyy51Bw',
#  'rNIb5eQtEHf8UvGCISvuYw',
#  'i_5PaxI8DK9EErsHBdwP1A',
#  'PwJWwvIhn1L9yjoUnPyOAA',
#  'UtfuLzO7c2N0m8oogeu_SQ',
#  'HThZ53HBR4UktXa2TyCaaQ',
#  'pEa6tpYyl2NDOPfY1OfFyQ',
#  'pj8Y-5vfbRitnnm2xJFH9w',
#  'xYOETY4C57qgs0ldtDYX_Q',
#  'wADYKG5qIyJcq7iisTPlPg',
#  'dE2gEdVmQNgLNkJAoiGSZQ',
#  'XpTNCVbO5wL1DtDyKzKqfA',
#  'eoooZrFnFZhRVuBH_LGcQw',
#  'skW4boArIApRw9DXKXukkA',
#  'fYXCk6Usfd2wzyaBBIM4dw',
#  'm1ohyfs8gcS9X-ZQ3Coj2Q',
#  'DJZQCN0NUej_EtviN4rUlg',
#  '6LCZLGa09Qifn6rG7-DNrg',
#  'bHzHDhAtgyueG2UwqKutqw',
#  'yD6cXmbmhRxcd3Y84Ry5wA',
#  '_kSaLnFZIEpOZEg6ZIxKvQ',
#  'iJOwwuhHP_0BCHmpmJ8l4Q',
#  'I6DZQ3EvWniopa1O35titg',
#  'B2TRCYPklp7a8Ipcz5y-BA',
#  'BWo8s2skxQGZUgVooK2HZQ',
#  '1b81nmM0JQJc2ogciZzfhw',
#  'fzZxqe9XAtKrx10959x1Rg',
#  '-rGocJekjtLnrn3MYKxJVg',
#  'wAUkOyvAoyE6F7zuQ3g_UA',
#  'YSQkA13M3dVSrWynCqybaA',
#  'J-ciDDEdIHMcChGIyKZnOg',
#  'XBdaG2kQ2Iz9VNGPZokjYg',
#  'MKHJy86fkFnMAhZac6wuLw',
#  'WIv5kTb_P3jnngPkMeRRNw',
#  'C_EtrXTygRX5RTUOKtO6Dg',
#  'DmaGQqKOjxkJtHjnxuXjAw',
#  '10wt8eSXI_PZfl9dRIiWmg',
#  'AbtYqoBGuvlWmR1gU0c3XA',
#  'WFRro-8uIBpKoJ1VSKrpdw',
#  '7x76ngzub3j4PijMHm71nQ',
#  'KRhAC2scnvxlGuiiOKfzDQ',
#  'MeptjglT9R6k0PyQRq5-nA',
#  'ILi7_ep3fBfUZdJrXLGW2g',
#  'vA5MHe9LqNQcp8k_CaFkHg',
#  'OvMc0NNMFdiHVoU5l_y6Iw',
#  'pzhvHwe_3-4JYTC-wXDJpA',
#  'NDHgJsy-4Lb6WhERPXPs0A',
#  'owQgiBoTu821TG8d-w5shg',
#  'X5fWO9e82EICHXzzs6eQMg',
#  'PvJB9euN4qsH0yzTBzWpmw',
#  'gIdsoqeal31OEuBXhAaPPw',
#  'aplm3-xr1RRgHAMdDS2OUw',
#  '1i78w_Du0UIgwnD7iFckQQ',
#  'iJfAoWtETn-F8WjC4g_hgw',
#  'WA2dW8HafdFte-dEWStZzg',
#  'F1hbIYD1lNzbprtckd7bVg',
#  '-OIUunijjcq_ZzyyQhPPFQ',
#  'ZrELIjB9mi7IkvGyFdIpNQ',
#  '3nM3QNlex3OkNqM7FZTFPg',
#  'hxGPQvQLwMQzOz72Cx8UGg',
#  'piLUryfru20TQEafOj4QRA',
#  '5KG0RjpG933SOPvBExKouw',
#  'VJEzpfLs_Jnzgqh5A_FVTg',
#  '1UNorskttXSWuEcgzKzXcA',
#  '0qbMXG1Aw3a2beoQhU52lQ',
#  'WYrITmacXpS3twSpf6SkPg',
#  '9aQYLiO49rX5OHJi46J0Gw',
#  'NoaeOhk_wLceJqFruhRX1A',
#  'hUX1yAimviBIhb21D_KtcQ',
#  'RVLF2RaStLkJiQCqBHknDw',
#  '0JoB3ThhI-DS78-1Ks1EUQ',
#  'D4AJVjAiJULF04BjN7bhiA',
#  'p2SakAsYqdAvLqPpAhkekw',
#  'SVV1VmybJGXGge6nFuHy_A',
#  '-tx2Fb2MWnEqiCmr23uOrQ',
#  'HTJWXGmZA5dCBV9ylvLjUA',
#  'IKXaAODca0KYqr8Fo4sgjw',
#  'K4fLZqHVuJjGZjM5iv9B6w',
#  'S0TBIuX2tkMjM0SCILJrtw',
#  'dVKHPRNhgpclJ-E2CoZiXA',
#  'z-wYdFvKCc-4hSt-MW0B9Q',
#  'VMIsjL0oKUtDFPFbhqIVoQ',
#  '7T1VAYHIS3cgsDj3iS6JWQ',
#  '17Y8circEnkMMXKfLo8Ztg',
#  'bJazyxju69RqC35WSSY-_g',
#  'HsRyFKdU70DKYpqai2HEIQ',
#  'tlhv-IT6zokg78sG9t3mWw',
#  'xEJAn8fVO6d2Cx2NB7yGRg',
#  'z5YxP_jyIU7dRKUA7V_H0w',
#  'DGvkU7CkdBs6lNbncQmF3A',
#  'MF5-JPr0auUkY_WLTTVUaA',
#  'fQXqQ-3pdDzOBGnZPr1qgg',
#  'rBIwGqpV2CKq8UBJ5SLSOQ',
#  'e4lrDi48799CTlV6CYVufw',
#  'FHNIvNgh3fS7VZQq2Y3dsA',
#  '-Wyh5nrgFXVlkkbb1xC1yg',
#  'LY6OCkHEwfZtdOoQawNkWg',
#  'zJErbOQMKX-MwHs_ulV7DA',
#  'qZk3lDvVwOV6FcCnDOyo4Q',
#  '3DDRYqCzc3Yhh7WOpNh7tg',
#  '_O_KBH1MStcUkS1xk5pxsg',
#  '3J8PwNptOmUSwPI6WTTaiw',
#  '7EdQA9eGwSuQTzomG4QBjw',
#  'NSOQiCdvojQjKOAXcr8WVQ',
#  'RjISdNawGnpjsewMTSGgsA',
#  'TYmX9kGUoktbJZvaS_7zNw',
#  'pCZDimMP8kdkc6TnVPzoYg',
#  'mmBwAe9q062vKWanRfoagQ',
#  'uMT7H0shZK4-pQ_J2qMEWA',
#  'GphyhvJ8tX-ZZ3cDxJwdZg',
#  'kxX2SOes4o-D3ZQBkiMRfA',
#  'FsRAHiYUERqUIeGVt49svA',
#  'oh2wCX3pzTTEYaynLgmMQw',
#  'MUQDp-1rzSN3lCjUycNLug',
#  'FGd8MNC_IArIpxeXe_5u8w',
#  'eW-x-E1rmHeDxgymj2j2Kw',
#  'iBHCv93BnYdSR1gnmUjhpg',
#  'LnZvGYbqozanOSevcftnrw',
#  'lqBurWf5LxIhUQ0HtXTu_A',
#  'A2a0dPK1W4E1pMaefhNxBg',
#  'TyFYyn5hP7TRXOkAO-pRDw',
#  'RXItVN-qOBgbp_vBalAkOw',
#  'Qnbwhb-L5q4mLIBdF_DUOQ',
#  '4ID028tc3wG2QT2LS-iLHQ',
#  'jULIPydhMj18KOI5OHTwfA',
#  'XHG8JXyUm4MgmrZ4BhqNdw',
#  '7BmboJEmyQ_DAgTCoCgpgg',
#  'WkNJ3FnK5WVW3thVUe-WSw',
#  'jsUzVBGEIoer6l_fxbad2A',
#  'qNdDhnauAdhkWyZJHVqUNQ',
#  '-RzbRfPnKcwTixtokN-p6A',
#  'hTUSv9wNM1XQXW2b3NEwFA',
#  'kEeM1rPVm2npocfdyT_0ZA',
#  '52KaQ6LSMgzjqhDuHBheJQ',
#  'b6hV7LXWQawY6OF7Dgmf_g',
#  'v7YRuZlPMwbi82q5I15few',
#  '9uHEhLKTVXATCt7JSvUsCg',
#  'vixUPc4ab4eeFVWnM4cngA',
#  '4nmSdHijY4skUHuHebtOvQ',
#  'rDYU2Zsj1rKYcP31F4OZTA',
#  'sCmhmw-iSQEJYDQa0V-EGg',
#  '1xb4MBAUGQRU7n5C-WqCtw',
#  'F5Oy_o1JR9lagi_RsEoJmA',
#  'UjXH7iq8eYauQoGswkxGYw',
#  'kkcQYuF3w5iHnHMf0EnRhQ',
#  'Pab9VzWLe20vrdGn0rxNfQ',
#  'W-WPA5pOLtJujLST3Y3XJA',
#  'fnjKM583kumn7z0Z00Rc9g',
#  'zzyx5x0Z7xXWWvWnZFuxlQ',
#  'jSs2iTKe3Mb-esVU3FmsDA',
#  '8wQq1jGlJ4hj691c7WLdQQ',
#  '7yPzOek7Af2dKWGYKpcHWA',
#  'LUXRw-mr9emGL2gw4otvVA',
#  'zspnOaAN4jpseR3X7YtX5Q',
#  'JAMmjTFdUGBpV24K1riSjQ',
#  'vUrTGX_7HxqeoQ_6QCVz6g',
#  'h4aJWIS8drud_1iD8FDIJg',
#  '-0fvhILrC9UsQ6gLNpZlTQ',
#  'aJet5OBtxIEbmLZwA4VphA',
#  'LdK6Tqr9-QK8eNezCUes9A',
#  'o9Gru-QFoxGK26FSWRCLXA',
#  'mFE9V6LPpsDRUQLEBsBRRA',
#  'r2cjbHG_WGWUkaPCbLpo-A',
#  '0eJ6GTYQerMPEndBIQmXAQ',
#  'cuf0GPuuMwB9uRR8HSuT6g',
#  'Oyll2luYo8tvaUgR-m8UlA',
#  'SiHnuDYGCzm4NeMQILPyzw',
#  'DytKODMqcvQ7MWA0NN2uNw',
#  'gCcJTKC40CL0XtYYGfcXDw',
#  'NSDhtsrXY78oZ8B3MkaxnQ',
#  'S8qm3P9q2UtSyKP5AKm3ig',
#  't5RIuLUvE5fxr0TaRWxeQg',
#  '9EkU93HxB6gMAvuvkfVqVA',
#  '6bF90BK6byDOVcPtKWe7Qw',
#  'HhU92tUeDvBGaFfgQHISAw',
#  'ss1oWXeNNjq7bd2bZvR3pA',
#  'dGLmZh5xXBbJfTGRLh5epQ',
#  'WRMlifrYLjRY8q5YUUbfZA',
#  'fFA6bjWbq724vB1tW4V9pQ',
#  '71cUrGn9enOIIiPtwqp82w',
#  'BkzPB-keyU1Ri1Fd8YuiAw',
#  'wnsvzUn2eqJqGJalrJiT4g',
#  'wCluBbW9nzS7MEMFltMwJw',
#  'a4H1mxquTjZnREriPff2-Q',
#  'hSjvNCjp6_3xmnfNmiDAeQ',
#  '_msFUghqBbYNmO8grFJNAQ',
#  'qjGS_7iaQDpbVhS6W8qkHQ',
#  'EM38BqTh8q4V4I8WEmOWnw',
#  'Ug5KqH8kcE_PhbivCa_2jA',
#  'n09hgXTl3gsDo1lLDvHZGQ',
#  'pKg4NleedNE_SxkfN_NlTQ',
#  'Dx3s4k3_a1XcM9k9Fvi8dA',
#  'cRJIf2i9LX8X8DKDG2qjiQ',
#  'Fe5Q2saATrFH4V-y6yhfAw',
#  'FnEkr6LzjuGsg93Z7fkl7Q',
#  'HoSD12A8J7m-q-F_Z7s7uQ',
#  'Bmh7d4yVxpgLPQ8KLcy_4Q',
#  'wsr5zfPb6OZX4mQ7S-D8rQ',
#  '6IZTPy1g5ez3SCbKgKWwkA',
#  'KGo93t2QwqryygJXGv9MTw',
#  'GnXLe-SHVmlvx8vcU-I68w',
#  '3sdlpskDaXr1P59BYjGoFw',
#  'uu0n1Xn0Hl3u9aCjFcN7Xw',
#  'fB_VJEJTIMyWv5hC9T-xwA',
#  'cNfeKIYIv07oxqVozMbjpw',
#  'yYpU8EWucx32OYIIHqP63A',
#  'wP0SSjU7R-m9j-VRhOCzmg',
#  'MoU6F7B9bSLG6Ykan-9G_g',
#  'Xbxh--kHUKJgTugsYcBmsQ',
#  'aTUDMqpfoXbvYxL2dEenjg',
#  '4_W5pstoN1166TGjjPOrMg',
#  'mLJJa9r2h1yoh1dWUqekKQ',
#  'OL9CgTWy7rU2eNq6F13JBg',
#  't0u_YYND1OWPDGUL4bCWbA',
#  'N-MVwAcmsQDZCxbZjZhPDA',
#  'zxY4DgtXsVHihSUpsmwamg',
#  'AWJyivVwe3t9BO-k8D0ynQ',
#  '8CU6Hj2SBPC6nhSEHLCJvw',
#  'SADPX8WX34EQDj_jqtacMw',
#  'E-zz8gs1riWX0r3hxAn60A',
#  'roc-xyyzN5b_nImb0NdRLQ',
#  'wdMuaYX5_RmPEx2FYgUTzA',
#  'uE40984_YDgVvPeRpFcCaQ',
#  'l4-OFqq_9kRhZNbd3ttM5w',
#  'HTqXI5S2XcSlh_ylx9sE6g',
#  'RYLGohzuMvtADK19ZfbBBg',
#  'L6oy16zB52ZkaD6N8-D-Yg',
#  '2j7i82BNAalfIL75KninSA',
#  'mDd3GFkYQKXhTlpm7SHtCQ',
#  'vM3W3-ILN10eaF1HVJ8m_w',
#  'NMtUD873aWrNjljt3VOcFA',
#  'KMQrA590JiprwoOnu4UKVQ',
#  '7UJZQyroV-TvndJabqiXqw',
#  'HUp0fqvl0XbZmrCp5FfBjw',
#  'Y8JqVTJ5xsLu3KzfIyRsXQ',
#  'X_X60vlWlPLWcW97LPrSjw',
#  'ZAPCUuZBUKbhLF5tiyxDig',
#  'YIdYc6tQIFRJPNIaPBupYQ',
#  'fpde_5H6mH5ufv1tUfBAKQ',
#  'kPl_YGxEiYLQZmYI8i1Ksw',
#  'j99PtxlKTW_u5alE4jiqHQ',
#  'B-DiQpcSTJ7oMMnwzbAGTQ',
#  'TxT_v3sUf5XU6vi1iAsdhg',
#  '6CsLAjWXFlLpErBZEmGQ5g',
#  'cb1qOn3wAGVw8oINX4tqFQ',
#  'bpEiVcivZFHixcDGKXQQJA',
#  '5ezrDoezdUlJpUa5Jg6dUQ',
#  'Sve_KZ4fithOnqVm1brg8A',
#  '4RMHlggaIdNibPUJPVEd6w',
#  'n0GmfsLp0Ea10X1bbH6Bqw',
#  'deVwhY98J_r69DVedK2x8A',
#  'GdqZaRx-gN8IxrmqYTXcbA',
#  'pe01uqQsa6raj-4HWRjgGg',
#  'dIwOZoxwSpPUV3eMYFzPqw',
#  'WXwRcHGaV8W3twAOJtWlew',
#  '0zWAsCBzvuCI_Ydx7yH1Jw',
#  '50MNOCMK3OxqR_VL3Bsupg',
#  'p4_cwv_NAFduuDz5RcTLeg',
#  'q10gQHRRga0o0A37YsvodQ',
#  'qSjUgS1CG2_-MzSWHjvO0w',
#  '0a8t_Th0jtWUMmtq0q2dqA',
#  'pOKlPUu1ecsedBwKqNfWUg',
#  'BzQiDngZIG0MfbjJFg-yUQ',
#  'Derr7dcpu_BRwl8OwGQtyg',
#  'JLggLAox_ABHrGERr2zybw',
#  'KgozvZ1UFfXuJToqe8CfQg',
#  'Xq-8-I0U8Artr7d70SjX-g',
#  'RhRQhyGHurL9WqRoAn7luQ',
#  'nSSoWHnmdkTRj8MA3Gj4AA',
#  'pBJ9hVagqI4dwj6wPKTePA',
#  'KlAocfljVDKA1VyXoiCrPQ',
#  'DNA6jRC6wt0QXO4zN-BdXw',
#  'rzDTtIfcxUwQBLKG1RSQGw',
#  'Hxt8qo2hEraEbxEO9k4TVA',
#  'KFmyGXB4oW8JXw6qywhBYw',
#  'mNNBDRkF0c2oGdeKVpv8rA',
#  'PQva56jc2JZ5J2ZSqAWubQ',
#  'cKSGrUPLEMTcA8oiIDn_RA',
#  'ALVX2hbStpIIRvnv1_7x7w',
#  'SJEJgULLv4uxNJp-55NGow',
#  'H47H_73y7aZ9KHpzct-xBg',
#  'NYJ1PTYcQhQ8aVJiBPgIQg',
#  'Fkl9q6P0PIAY1_JQxbqc7A',
#  '9hlCvuR5yqPNQZ0Dpgleug',
#  'nsZMsV91PfYQ8w2lbktpjA',
#  'v7ibuvyZutqZ7pjMCH1exg',
#  '3dl7FI3cG8C1v3uaj4_78w',
#  'yjcpRvhOtqgu7ykZiL4xFQ',
#  'Ac6NdLwXzX9EWqqWxx94ZQ',
#  'MnCs5pIA0BF3FN7T6wTNyg',
#  'l_u2KGYWvx2LBcRV1G-wyA',
#  'Hbd-b99EBCYTZfSaZz3tHQ',
#  'r8gB1EKj-YDfmfOm30TSHA',
#  'atSO7SYsHhKVSML1g8wDjg',
#  'bSWL0YxfawjS03_g2kgujA',
#  'ipaHtb0jzsnzuxkjQxvxgQ',
#  'y--UQiSyVPAmWjRkZ9tdPQ',
#  'PU6_b7Z5G7fZRjiDMkoFeA',
#  'NnlQhXtuVOVjUFYB1Hqp8Q',
#  'NeY1bH6IKJxnn4YAixibsQ',
#  '-VGUpTEsCUE9gJk50gbU6w',
#  'Bfjx1m4INbd7DMQ9pMfYww',
#  'd_tRshM-w6S4QxE4VVi8tQ',
#  'O286wXm4mcznQn_1JieD1g',
#  'QrIV69RPS4LTpIwPoL22_w',
#  'jvCNijeK9ZOf2Vb6pGNySg',
#  'Ak34oJ8zxN8Av7dxS9T8IQ',
#  'woEzdPOYu5KmRHu1NjxKYw',
#  'RZtGWDLCAtuipwaZ-UfjmQ',
#  'alUk6OwNhofyc90NDMDY-Q',
#  'kimOwpoIWzJJx7NHTAj74Q',
#  'mbglgx3nbRRPKxh0SxDjNQ',
#  'LDepg4jhTLwxY2YN6YGHtw',
#  'hJnW5-ovJQkecq0EZhHaKw',
#  'RNEhva5S8AlvwgaF6Z-l8g',
#  'QDvQmizwCiFGf3y0Om9jyA',
#  'oiwRXkajqqT4Yq5SpEsy3w',
#  'nt1jLHRIeV5HqB5PfFWbKA',
#  '7yBuPIRjDxq0urQzjp1g3w',
#  '4ZSKrjtl_B9ytuR0o1PvEA',
#  'YG7qCDqFE_3EieWB_GQSlw',
#  'OHplb2m_dKPXY46mS0CqJQ',
#  'rMokmPwVXuftCVKVgSBlPg',
#  'iX-B-N84nktxvhSwTYSfDw',
#  'kqbZ8euPJFYrIbeMJXPkzg',
#  'tkJRnUUhHqp3XB6SEQC7-g',
#  '6_HDH0EIt2QvX0adkZdsTw',
#  '8QGXgKl1aH3W15YYVcSixg',
#  'NSDifyQNkKyPUV_f23ldaQ',
#  'eLbKuFpCtHEjCkoWkDDk7g',
#  '5CZIGD5oNpS5gQTiVxHCdg',
#  'eM5CowLA4lGmATovJrLRXQ',
#  'JlbPG1auhjZcLCAi2lG1vA',
#  'xz3z2vqP8XkAsA11HA9pDg',
#  'jQDXPPEfRlGiiH7kmRfM0w',
#  '2GYg3liJ9-m6Z67L_4_BRQ',
#  'WXVAGgrGtRmlgO5i4fqrpg',
#  'feycIWpE_lOM9iPu1FMmww',
#  '0U4PsGJynuzEBrEn1HaU7w',
#  'CinrOH8rMB2hEvPY_iFOHA',
#  'jDSWTtmsrq5_0z_ZK4Au3Q',
#  'KydLm9nUhLSK0K6VnDLVjw',
#  'rytqWB6v6AAAxZiqy7Flww',
#  '4i1to26tzHGWDpquEeazwg',
#  '9TNrkJ8HRO9ba_y5ZDqo6w',
#  'YA4OQvZFowHG4_78xis7sg',
#  'e1L7zxPnI9TeCqFexdstdw',
#  'JZVK_yoV48O_2gDykG_1Ow',
#  'c6DUOuLuX8pKVNgKUlZf9A',
#  'WYulP4JpEVnFjhydDoxWjA',
#  'NKP_jXl7Gn6hkiR8D206Gw',
#  'qfFKVxDqFbPtBTlKGQDapQ',
#  'UkN-K9T_hDLGD9m_AAtXyw',
#  'SczLxo7EPukLqteIJ_c7OA',
#  'lIOEBs50Uk45ehz7zrtYmQ',
#  'G5aLEWu4uOCSXGlHE_LZwA',
#  't6KsC3otfr9PUK3d0pSS3g',
#  'WMjy9IgiiuxN1tenNvJ4ew',
#  'fDZjJvs3sikPHqRs_4HPTg',
#  'umqAlYC0OtFjFI-sTNSEYw',
#  'kuof8pQvg5dSGXzBdlsIPA',
#  'pDurCski6kcl8mcXmpcKKw',
#  '2IOlw5AaluuCSci3Bd0u4w',
#  'YAYIiWShAU4R9z-xNUqVig',
#  'Udlivg8oVF_JRgfL5TV33w',
#  'QPwEwRE5jiOS3d8IqwxVbA',
#  'd6bUs1pohZndzv-76YpcYw',
#  'eRa4aOztXDs0px7bUakoVQ',
#  'gSw5N8h5lpC4XGw_nthyrQ',
#  'uymhAMBgsI1vxOd--8J9Mw',
#  '0QdcIaX7Mp9cXLXt-zv1BQ',
#  'bH1HbFxDv6WquY-vK3fwww',
#  'AcMwma_tRlmAp2BTDjZ3Kg',
#  '4SQ5uczVt66-GGGeNQRfEA',
#  'vCHNWdW-ys-nWUx3Cpvk8Q',
#  'iB8TMAjQEUfldgolrRyKiQ',
#  'lGw75AaWNUayMJxXD5ahpg',
#  'c6fmdw06KPAsPxzvwyRBAA',
#  'htO_nlxkEsYHzDrtbiUxew',
#  'DsKzHnkLKnxZTVsFpts4oA',
#  'eznriqn0sKt0D594H5OCcA',
#  'bguzzvkFJ2gPGvtvXwfPCQ',
#  'uIg5rdP-VmiBa-3kHa7AHQ',
#  'iTqSLah6DnnXGaYQWDl7cQ',
#  '0lQKj8f1CJSdLJRLYEsqnQ',
#  'gHMN4jk8kjG50CH-IRY2Dw',
#  'AxcyIxsjJbRNG2RFTguavw',
#  'iQMGNjgTqZWhgDH_nGwKfQ',
#  'Rk-qL4enpuz3WA3xKetnzw',
#  'sHZP73HSW1eCBorgi8pUjQ',
#  '_PQzeo8P2sGczzFEifrK-Q',
#  'CMLS5r0rOAWqlnu5lnC0TA',
#  'zNi8ceY3sLBXZoTUstjrvg',
#  'Gmj3Lrg0wHaJnzshCxNG_g',
#  '7b-4PtkVI_qZ76jp4rz8Bg',
#  '7crp8LZA4HbkMAKyh8Wcdg',
#  'ihXHRu99MxQDiy_p1FKqhQ',
#  'zshJGJPip5oKjocYXhLofw',
#  'NBlB85ch_WCxYJ4fPWHxJA',
#  'K9gaM9XdGqGWsQMdjpxFIQ',
#  'ldTsXru9q1V-aC6iM7BH-w',
#  '9gObo5ltOMo6UgsaXaHPWA',
#  '1t_QZpj9jTg-VSQDnWM7PQ',
#  'f8S-27ATMBpRwcXkRPExZQ',
#  'oxo-zgeEHH_kzDSEbZe4xw',
#  'uUYr4mxdptgy8faIxB-8Ew',
#  'uwF2zLAnZZ1SCwEF8QQKQA',
#  'LrMVQ2TlZyS82qTkDM9mxw',
#  'qrVCN6M272dDdEKPB1E44w',
#  'xWvxtxqvcLSZSraR86MT8w',
#  'fFG_tetXNiW9u0lN1W2dBQ',
#  '9b0Mrvs6uJu2jJqet_Jwew',
#  'Z5po0aTuzKKblek5y6Sp8Q',
#  '0K66djyR4yvBG4mEW5y_xw',
#  'AwmeLVLEfdFoCa0LaF0UYA',
#  'xJWchnP9x_5STCQzEazQ7Q',
#  'VXTypAQ-BwdNJyLWHQEl9A',
#  'jj9-k3CsTJz0a3_pP4RkJw',
#  'GzWIBhi32It2LMgX2-c_hA',
#  'dVtFSZCtuhCNaUhWfo2vng',
#  'GNnDvJwtA9C1XFf-yv4KVA',
#  'muL0Op-fX17L39-i9L5Gsw',
#  'aGlcso7FnM30cqCzEk8xNw',
#  'wDhNKCkOObNSw54av90ZmQ',
#  'tqBkgu2wyCjYBWuTQoy2aw',
#  '7CXSQYrIep0jdvoYPUIGdQ',
#  'IwjkFCbCyovE72tT2ekr6A',
#  'i6I82bBMgxkV8RU5JDypTA',
#  '8FALz8g6oaTca0ufiUuF6w',
#  'mLDJH5ic5_digOyWxBA71Q',
#  'L2pmVQMrpY-yZwZkZoRt5g',
#  'Gd6yIH-qhf9uCdtUWs382g',
#  'fAKJLkzh71-K8ra82xZJWw',
#  'E3V6zb2wpHEo-1dfpIaUYA',
#  'bFO_XYnYMDF1GMY9LK3oxQ',
#  'cDPHu4gct96U0BHIdL4wiA',
#  'D2gONomZQyRjxR3TMHJovw',
#  'b1T39R2EPxuOXJIR61j1DA',
#  'cdqTpsr110wSNPMtLCPh7A',
#  'toMVWIsPJmS7-LiLAf2AfA',
#  '8YTbOl9x7WSJwZuKgCSF0g',
#  'FKrP06TDAKtxNG1vrRQcQQ',
#  'j0D6RaGSZMjfiOfux8aKng',
#  'vR9SKMvXCXyrl6u5ouWHBQ',
#  'R76nXl5oTep-d1ZGPZSimQ',
#  'dCFptNgnFQ8t0IG1Mj1NQA',
#  'BJnnPDTZXsyXou42HnHfHA',
#  '0Lug9lpS3mdky77wsr3wmQ',
#  'uE_4H__4kj4Xjb115_LBvA',
#  'MN-Em6pY0ZXZQsLv6uBhrA',
#  'NB9wGhMqy27suWqNzk3laA',
#  'FIQZMB4G1pfqOAByuJ1SYA',
#  'a93-oNkJsUWOCiHu5O9xLA',
#  'LACylKxImNI29DKUQpWuHw',
#  'GKPtlxe7wdCWZ67Fx904dQ',
#  'DRnvSL_I8MLuTLhl6O4JBQ',
#  'zy7uNOvpykrq-XlmDY_wHA',
#  'rgkz13vQnU2WFZBQBMqMAg',
#  'HSXvx9ajd9cGDzYIScmrig',
#  'zbu2BgZJMCScHtyFnyy6YQ',
#  'RaPhU7UdbjlbpR1reCEwVw',
#  'eaDZlSuVS0EY67Ke6pRP6Q',
#  'fskPbD8G1DDQbCslHV-v_A',
#  '3slJKckw5feGTOHopRTiPA',
#  'M0vE83RgTuYBhd3qkAIdpA',
#  'ra0Xp7uUxkdVxawtdZSrEQ',
#  'jDpTvYGJWqjIHw5OQKBINw',
#  'KqvaJX11rb4Hp70D8Dw4oQ',
#  'cFnBmQ8recCHLF1-KNXkiA',
#  '7E0VkDqc_86Zz9d5kQJCJQ',
#  '1XBxnolv7ZpHQBVE_gBAWg',
#  'z5qihVAArG351hpN3riTOA',
#  '3hFAXKo69x2om7z9OWG7kA',
#  '1wwH1dnkTtDnCfpHORlgBQ',
#  'vFaZ55TFdW5GxtsS_0VKXg',
#  'Dv6RfXLYe1atjgz3Xf4GGw',
#  '9iBlpXwgBFLVnx6RmHsiCQ',
#  'Mr9YZZhMTG7Xk3Cr4awxPQ',
#  '9PCPV34KV1B_E3v1IUi4tQ',
#  'WneyRrLCxcbYn3qo7p58-g',
#  'F8yozE3NWnImNApHO347gQ',
#  'n4Ns3xLRhpkRwglwiQGKVA',
#  'AfassS1QI0DHsqwuof9-lA',
#  'BJphaOPeTtqUFF5pauQEhw',
#  'UhSVDwQFW6mKmaEA5OTU7A',
#  'wyT044EirxfcotSSqG_S6Q',
#  'voBKS7xPilHv3iWD54SOfw',
#  'IbdpXTUI56Jb5uCqUsKzhw',
#  ...]

# %%
review_json_file_path = '/Users/yumin/Desktop/Winter2024/421/Project/Data/yelp_academic_dataset_review.json'

# %%
# Filter Review json file to only contain business_id in Phily
review_phily = []

with open(review_json_file_path, 'r') as file:
    # Iterate over each line in the file
    for line in tqdm(file):
        # Parse the JSON data from each line
        review = json.loads(line)
        
        # Now, you can work with `data` which is a Python dictionary or list
        if review['business_id'] in business_id_list:
            review_phily.append(review)
            if len(review_phily) >= 10000:
                break
        
review_phily = pd.DataFrame(review_phily)
review_phily
# Out:
# 58614it [00:04, 12688.17it/s]
#                    review_id                 user_id             business_id  \
# 0     BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 1     AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 2     JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
# 3     8JFGBuHMoiNDyfcxuWNtrA  smOvOajNG0lS4Pq7d8g4JQ  RZtGWDLCAtuipwaZ-UfjmQ
# 4     oyaMhzBSwfGgemSGuZCdwQ  Dd1jQj7S-BFGqRbApFzCFw  YtSqYv1Q_pOltsVPSx54SA
# ...                      ...                     ...                     ...
# 9995  OBLJXmWiodkgC4L7k8U9hA  9pj8GGO_d83EQvf5GWJcIQ  7mpYTDb24SywNMRn3yeakQ
# 9996  sDJhX6civc0v-6znsTkgbw  prpyhhJBEsCnvFGQl6H8aw  LnZvGYbqozanOSevcftnrw
# 9997  MgPj_tcktIiVuPsNyVoLOw  XQIah0kkExdDVFSRGRfR6Q  jsUzVBGEIoer6l_fxbad2A
# 9998  QDy4gBrTT4MBtHmPiWGmtQ  rnbJGCSjeTwML9Qn3Lk1SQ  qluIWCzDpeZfddykm_2gYg
# 9999  t9bR6-7dIJeHxWF3yZa-OQ  3z2FQKEmFZ7zKuFIG1B1qw  9uHEhLKTVXATCt7JSvUsCg
#
#       stars  useful  funny  cool  \
# 0       5.0       1      0     1
# 1       5.0       1      0     1
# 2       1.0       1      2     1
# 3       4.0       0      0     0
# 4       5.0       0      0     0
# ...     ...     ...    ...   ...
# 9995    3.0       0      0     0
# 9996    4.0       0      0     0
# 9997    1.0      14      1     0
# 9998    1.0       5      8     0
# 9999    3.0       0      0     0
#
#                                                    text                 date
# 0     I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 1     Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 2     I am a long term frequent customer of this est...  2015-09-23 23:10:31
# 3     Good food--loved the gnocchi with marinara\nth...  2009-10-14 19:57:14
# 4     Tremendous service (Big shout out to Douglas) ...  2013-06-24 11:21:25
# ...                                                 ...                  ...
# 9995  I had dinner here last night with my family. W...  2014-10-30 21:50:23
# 9996  For some reason I was on a recent burrito/ any...  2013-11-17 20:39:46
# 9997  I will not use them again.  My cleaner cancell...  2014-02-28 13:01:30
# 9998  My father and I were attending a legal seminar...  2011-04-26 14:56:29
# 9999  Slightly overrated but not bad. I respect that...  2011-05-29 22:27:13
#
# [10000 rows x 9 columns]

# %%
business.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %%
# # Extract user_id from review_phily
# user_id_list = review_phily['user_id'].tolist()

# %%
# user_json_file_path = '/Users/yumin/Desktop/Winter2024/421/Project/Data/yelp_academic_dataset_user.json'

# %%
# # Filter User json file to only contain user_id in Phily
# user_phily = []

# with open(user_json_file_path, 'r') as file:
#     # Iterate over each line in the file
#     for line in tqdm(file):
#         # Parse the JSON data from each line
#         user = json.loads(line)
        
#         # Now, you can work with `data` which is a Python dictionary or list
#         if user['user_id'] in user_id_list:
#             user_phily.append(user)
        
# user_phily = pd.DataFrame(user_phily)
# user_phily

# %%
# Merge business and review
df = pd.merge(business, review_phily, on='business_id', how='inner')
# Only work with restaurants
df = df[df['categories'].str.contains('Restaurants')]
# Rename stars_x, and stars_y
df = df.rename(columns={'stars_x': 'business_star', 'stars_y': 'review_star'})

# %% [markdown]
# ### EDA

# %%
# Missing data 

missing_value_count= df.isnull().sum()
missing_value_count
# Out:
# business_id        0
# name               0
# address            0
# city               0
# state              0
# postal_code        0
# latitude           0
# longitude          0
# business_star      0
# review_count       0
# is_open            0
# attributes         0
# categories         0
# hours            325
# review_id          0
# user_id            0
# review_star        0
# useful             0
# funny              0
# cool               0
# text               0
# date               0
# dtype: int64

# %%
# Descriptive Statistics
df.describe()
# Out:
#           latitude    longitude  business_star  review_count      is_open  \
# count  7389.000000  7389.000000    7389.000000   7389.000000  7389.000000
# mean     39.960327   -75.161795       3.776627    451.922588     0.637975
# std       0.032098     0.033920       0.530292    374.818213     0.480618
# min      39.876814   -75.249793       1.000000      5.000000     0.000000
# 25%      39.946795   -75.173768       3.500000    163.000000     0.000000
# 50%      39.951290   -75.163396       4.000000    339.000000     1.000000
# 75%      39.960915   -75.149510       4.000000    618.000000     1.000000
# max      40.141488   -74.965011       5.000000   1553.000000     1.000000
#
#        review_star       useful        funny         cool
# count  7389.000000  7389.000000  7389.000000  7389.000000
# mean      3.826905     0.840980     0.288537     0.395994
# std       1.261418     1.675089     1.037392     1.110522
# min       1.000000     0.000000     0.000000     0.000000
# 25%       3.000000     0.000000     0.000000     0.000000
# 50%       4.000000     0.000000     0.000000     0.000000
# 75%       5.000000     1.000000     0.000000     0.000000
# max       5.000000    34.000000    23.000000    22.000000

# %%
# Distribution of ratings
sns.histplot(df['business_star'], kde=True, bins=5)
plt.title('Distribution of Business Ratings')
plt.show()

sns.histplot(df['review_star'], kde=True, bins=5)
plt.title('Distribution of Review Ratings')
plt.show()

# Distribution of review counts
sns.histplot(df['review_count'], kde=True, bins=30)
plt.title('Distribution of Review Counts')
plt.show()

# %%
# Convert 'date' to datetime
df['date'] = pd.to_datetime(df['date'])

# Plot number of reviews over time
df.resample('M', on='date')['review_id'].count().plot()
plt.title('Number of Reviews Over Time')
plt.ylabel('Number of Reviews')
plt.xlabel('Date')
plt.show()

# %%
# Top 10 most popular categories
df['categories'] = df['categories'].str.split(', ')
exploded_df = df.explode('categories')
category_counts = exploded_df['categories'].value_counts()

# %%
top_categories = category_counts.head(10)

sns.barplot(x=top_categories.index, y=top_categories.values, palette='light:#5A9')  # Use Seaborn to plot bars
plt.xlabel('Category')  # Set the x-label
plt.ylabel('Frequency')  # Set the y-label
plt.title('Top 10 Most Popular Categories')  # Set the title
plt.xticks(rotation=45, ha='right')  # Rotate the x-axis labels for better readability
plt.show()

# %%
# Business with most five star review stars
five_star_reviews = df[df['review_star'] == 5]
five_star_counts = five_star_reviews.groupby('name').size()
sorted_counts = five_star_counts.sort_values(ascending=False)
top_business = sorted_counts.head(10)

# Create a bar plot
plt.figure(figsize=(10, 6))
top_business.plot(kind='bar', color='skyblue')
plt.xlabel('Business Name')
plt.ylabel('Count of Five-Star Reviews')
plt.title('Top Businesses by Count of Five-Star Reviews')
plt.xticks(rotation=45, ha='right')  # Improve label readability
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %%
# Clean review text

# %%
def clean_text(text):
    ## Remove puncuation
    text = text.translate(string.punctuation)
    
    ## Convert words to lower case and split them
    text = text.lower().split()
    
    ## Remove stop words
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops and len(w) >= 3]
    
    text = " ".join(text)
    
    # Clean the text
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)    
    return text
df['text'] = df['text'].apply(clean_text)

# %%
df.head()
# Out:
#               business_id                name      address          city  \
# 0  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  Philadelphia
# 1  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  Philadelphia
# 2  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  Philadelphia
# 3  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  Philadelphia
# 4  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  Philadelphia
#
#   state postal_code   latitude  longitude  business_star  review_count  ...  \
# 0    PA       19107  39.955505 -75.155564            4.0            80  ...
# 1    PA       19107  39.955505 -75.155564            4.0            80  ...
# 2    PA       19107  39.955505 -75.155564            4.0            80  ...
# 3    PA       19107  39.955505 -75.155564            4.0            80  ...
# 4    PA       19107  39.955505 -75.155564            4.0            80  ...
#
#                                           categories  \
# 0  [Restaurants, Food, Bubble Tea, Coffee & Tea, ...
# 1  [Restaurants, Food, Bubble Tea, Coffee & Tea, ...
# 2  [Restaurants, Food, Bubble Tea, Coffee & Tea, ...
# 3  [Restaurants, Food, Bubble Tea, Coffee & Tea, ...
# 4  [Restaurants, Food, Bubble Tea, Coffee & Tea, ...
#
#                                                hours               review_id  \
# 0  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...  BXQcBN0iAi1lAUxibGLFzA
# 1  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...  uduvUCvi9w3T2bSGivCfXg
# 2  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...  a0vwPOqDXXZuJkbBW2356g
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...  MKNp_CdR2k2202-c8GN5Dw
# 4  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...  D1GisLDPe84Rrk_R4X2brQ
#
#                   user_id review_star useful  funny  cool  \
# 0  6_SpY41LIHZuIaiDs5FMKA         4.0      0      0     1
# 1  tCXElwhzekJEH6QJe3xs7Q         4.0      3      1     2
# 2  WqfKtI-aGMmvbA9pPUxNQQ         5.0      0      0     0
# 3  3-1va0IQfK-9tUMzfHWfTA         5.0      5      0     5
# 4  EouCKoDfzaVG0klEgdDvCQ         4.0      2      1     1
#
#                                                 text                date
# 0  nice little chinese bakery heart philadelphia ... 2014-05-26 01:09:53
# 1  bakery usually chinatown decent variety buns p... 2013-10-05 15:19:06
# 2  delightful find chinatown ! clean kind service... 2013-10-25 01:34:57
# 3  ordered graduation cake niece came absolutely ... 2018-05-20 17:58:57
# 4  hk - style milk tea : four stars + + not quite... 2013-10-25 02:31:35
#
# [5 rows x 22 columns]

# %% [markdown]
# ## user-based filtering

# %% [markdown]
# ### Cosine Similarity

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity

# Splitting the dataset into training and testing sets
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# Create user-item matrix for the training data
train_user_item_matrix = train_df.pivot_table(index='user_id', columns='business_id', values='review_star').fillna(0)

# Compute similarity matrix for users in the training set
user_similarity = cosine_similarity(train_user_item_matrix)
user_similarity_df = pd.DataFrame(user_similarity, index=train_user_item_matrix.index, columns=train_user_item_matrix.index)

# Predict rating function as defined previously
def predict_rating(user_id, business_id):
    if business_id in train_user_item_matrix.columns and user_id in user_similarity_df.index:
        similar_users = user_similarity_df[user_id].sort_values(ascending=False)
        similar_users = similar_users.drop(user_id)  # Remove self-similarity
        top_similar_users = similar_users.head(10)  # Consider top 10 similar users
        
        # Get ratings of these users for the business
        similar_users_ratings = train_user_item_matrix.loc[top_similar_users.index, business_id]
        # Calculate predicted rating as weighted average of ratings from similar users
        predicted_rating = np.dot(top_similar_users, similar_users_ratings) / top_similar_users.sum()
    else:
        predicted_rating = np.nan  # Return NaN if we cannot find the business or user in the training set
    
    return predicted_rating

# Function to recommend businesses by name
def recommend_businesses(user_id, num_recommendations=5):
    if user_id not in user_similarity_df.index:
        return "User not found in the training set"
    
    unrated_businesses = train_user_item_matrix.columns[~train_user_item_matrix.loc[user_id].index.isin(train_df[train_df['user_id'] == user_id]['business_id'])]
    predictions = {}
    
    for business_id in unrated_businesses:
        predicted_rating = predict_rating(user_id, business_id)
        if not np.isnan(predicted_rating):
            predictions[business_id] = predicted_rating
    
    sorted_predictions = sorted(predictions.items(), key=lambda x: x[1], reverse=True)
    top_business_ids = [business_id for business_id, rating in sorted_predictions[:num_recommendations]]
    top_business_names = df[df['business_id'].isin(top_business_ids)]['name'].unique().tolist()
    
    return top_business_names

# Evaluate the model with RMSE
actual_ratings = []
predicted_ratings = []

for index, row in test_df.iterrows():
    actual_rating = row['review_star']
    predicted_rating = predict_rating(row['user_id'], row['business_id'])
    
    if not np.isnan(predicted_rating):
        actual_ratings.append(actual_rating)
        predicted_ratings.append(predicted_rating)

rmse = np.sqrt(mean_squared_error(actual_ratings, predicted_ratings))
print(f"RMSE: {rmse}")

# Example usage
user_id = 'tCXElwhzekJEH6QJe3xs7Q' 
recommendations = recommend_businesses(user_id)
print(f"Recommendations for user {user_id}: {recommendations}")
# Out:
# RMSE: 3.7991366409719123
# Recommendations for user tCXElwhzekJEH6QJe3xs7Q: ["Zorba's Taverna", 'Sky Cafe', 'Federal Donuts', 'Marathon', 'Spring Chinese Restaurant']

# %% [markdown]
# ### Adjusted Cosine Similarity

# %% [markdown]
# Adjusted Cosine Similarity normalizes the ratings by subtracting the user's average rating before computing cosine similarity, which helps in dealing with varying rating scales among users. Significance Weighting penalizes similarities based on a threshold of co-rated items, reducing the influence of similarities calculated with few co-ratings.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Splitting the dataset into training and testing sets
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# Create user-item matrix for the training data
train_user_item_matrix = train_df.pivot_table(index='user_id', columns='business_id', values='review_star').fillna(0)

# Calculate the mean rating for each user
user_mean_ratings = train_user_item_matrix.mean(axis=1)

# Normalize the ratings by subtracting the user mean rating
normalized_ratings = train_user_item_matrix.sub(user_mean_ratings, axis=0)

# Adjusted Cosine Similarity
def adjusted_cosine_similarity(matrix):
    similarity_matrix = np.dot(matrix, matrix.T) / (np.sqrt(np.dot(matrix**2, matrix.T)) * np.sqrt(np.dot(matrix, matrix.T**2)))
    similarity_matrix = pd.DataFrame(similarity_matrix, index=matrix.index, columns=matrix.index).fillna(0)
    return similarity_matrix

user_similarity = adjusted_cosine_similarity(normalized_ratings)

# Significance Weighting - Apply a threshold for the number of co-rated items
def apply_significance_weighting(similarity_matrix, ratings_matrix, threshold=50):
    co_rated = np.dot((ratings_matrix > 0).astype(int), (ratings_matrix > 0).astype(int).T)
    significance_mask = co_rated >= threshold
    adjusted_similarity = similarity_matrix * significance_mask
    return adjusted_similarity

user_similarity = apply_significance_weighting(user_similarity, normalized_ratings)

# Predict rating function with adjustments
def predict_rating(user_id, business_id):
    if business_id in train_user_item_matrix.columns and user_id in user_similarity.index:
        similar_users = user_similarity[user_id].sort_values(ascending=False)
        similar_users = similar_users.drop(user_id)  # Remove self-similarity
        top_similar_users = similar_users.head(10)  # Consider top 10 similar users
        
        # Get ratings of these users for the business
        similar_users_ratings = normalized_ratings.loc[top_similar_users.index, business_id]
        # Calculate predicted rating as weighted average of normalized ratings from similar users
        predicted_rating = np.dot(top_similar_users, similar_users_ratings) / top_similar_users.sum() if top_similar_users.sum() != 0 else 0
        # Re-adjust the predicted rating by adding the mean rating of the target user
        predicted_rating += user_mean_ratings[user_id]
    else:
        predicted_rating = np.nan  # Return NaN if we cannot find the business or user in the training set
    
    return predicted_rating

# Evaluate the model with RMSE
actual_ratings = []
predicted_ratings = []

for index, row in test_df.iterrows():
    actual_rating = row['review_star']
    predicted_rating = predict_rating(row['user_id'], row['business_id'])
    
    if not np.isnan(predicted_rating):
        actual_ratings.append(actual_rating)
        predicted_ratings.append(predicted_rating)

rmse = np.sqrt(mean_squared_error(actual_ratings, predicted_ratings))
print(f"RMSE: {rmse}")

# Example usage
user_id = 'tCXElwhzekJEH6QJe3xs7Q' 
recommendations = recommend_businesses(user_id)
print(f"Recommendations for user {user_id}: {recommendations}")
# Out:
# RMSE: 3.876181963362989
# Recommendations for user tCXElwhzekJEH6QJe3xs7Q: ['La Creperie Cafe', "Zorba's Taverna", 'Federal Donuts', 'Marathon', 'Spring Chinese Restaurant']

# %% [markdown]
# ### Dynamic Neighbor Selection on Cosine Similarity

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity

# Splitting the dataset into training and testing sets
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# Create user-item matrix for the training data
train_user_item_matrix = train_df.pivot_table(index='user_id', columns='business_id', values='review_star').fillna(0)

# Compute similarity matrix for users in the training set
user_similarity = cosine_similarity(train_user_item_matrix)
user_similarity_df = pd.DataFrame(user_similarity, index=train_user_item_matrix.index, columns=train_user_item_matrix.index)

# Adjust predict_rating function to use dynamic neighbor selection based on a similarity threshold
def predict_rating(user_id, business_id, similarity_threshold=0.5):
    if business_id in train_user_item_matrix.columns and user_id in user_similarity_df.index:
        # Get similarity scores for all users with respect to the given user
        similar_users = user_similarity_df[user_id]
        
        # Apply a threshold to select only users that are above a certain similarity score
        similar_users = similar_users[similar_users > similarity_threshold].sort_values(ascending=False)
        
        # If no users meet the threshold, return NaN
        if similar_users.empty:
            return np.nan
        
        similar_users = similar_users.drop(user_id, errors='ignore')  # Remove self-similarity if exists
        
        # Get ratings of these users for the business
        similar_users_ratings = train_user_item_matrix.loc[similar_users.index, business_id]
        
        # Calculate predicted rating as weighted average of ratings from similar users
        if similar_users.sum() != 0:
            predicted_rating = np.dot(similar_users, similar_users_ratings) / similar_users.sum()
        else:
            predicted_rating = np.nan  # Return NaN if the sum of similarities is zero
    else:
        predicted_rating = np.nan  # Return NaN if we cannot find the business or user in the training set
    
    return predicted_rating

# Evaluate the model with RMSE
actual_ratings = []
predicted_ratings = []

for index, row in test_df.iterrows():
    actual_rating = row['review_star']
    predicted_rating = predict_rating(row['user_id'], row['business_id'])
    
    if not np.isnan(predicted_rating):
        actual_ratings.append(actual_rating)
        predicted_ratings.append(predicted_rating)

rmse = np.sqrt(mean_squared_error(actual_ratings, predicted_ratings))
print(f"RMSE: {rmse}")

# Example usage (assuming the presence of a 'df' DataFrame with user IDs, business IDs, and ratings)
user_id = 'tCXElwhzekJEH6QJe3xs7Q'
recommendations = recommend_businesses(user_id)
print(f"Recommendations for user {user_id}: {recommendations}")
# Out:
# RMSE: 3.805438304578045
# Recommendations for user tCXElwhzekJEH6QJe3xs7Q: ["Zorba's Taverna", 'Sky Cafe', 'Federal Donuts', 'Marathon', 'Spring Chinese Restaurant']
